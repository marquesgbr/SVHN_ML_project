# %% [markdown]
# ## 1. Setup

# %% [markdown]
# ### 1.1 Importar Libs

# %%
# Importação das bibliotecas necessárias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import os
import json
import pickle
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, train_test_split
from sklearn.metrics import (classification_report, confusion_matrix, 
                           accuracy_score, precision_score, recall_score, 
                           f1_score, roc_auc_score, roc_curve)
from sklearn.preprocessing import StandardScaler
from scipy.stats import uniform, loguniform, randint
from joblib import dump, load
import warnings


warnings.filterwarnings('ignore')

# Importar funções dos módulos customizados
from ml_utils import evaluate_model, load_and_prepare_datasets, SCORING_METRIC
from search_utils import (plot_search_history, multiple_randomized_search,
                          plot_search_history_from_loaded, 
                          load_search_results, get_best_params_from_saved,
                          save_search_results, save_final_results, 
                          DEFAULT_CV_STRATEGY, MODELS_FOLDER, RESULTS_FOLDER, SEARCHES_FOLDER)
try:
    import xgboost as xgb
except:
    print("❌ XGBoost não encontrado. Instale com: pip install xgboost")

# Configurações de plotagem
plt.rcParams['figure.figsize'] = [12, 8]
sns.set_style("whitegrid")

print("Bibliotecas importadas com sucesso!")
print(f"Pandas: {pd.__version__}")
print(f"NumPy: {np.__version__}")
print(f"Scikit-learn: {sklearn.__version__}")
print(f"XGBoost: {xgb.__version__}")
# Out:
# Bibliotecas importadas com sucesso!
# Pandas: 2.3.3
# NumPy: 2.2.6
# Scikit-learn: 1.7.2
# XGBoost: 3.1.2

# %% [markdown]
# ### 1.2 Configuração do Modelo

# %%
# Configuração do modelo e hiperparâmetros
MODEL_NAME = "XGBoost"
MODEL_CLASS = xgb.XGBClassifier
RANDOM_STATE_MODEL = 42
RANDOM_STATE_SAMPLE = 10

# Configuração da busca de hiperparâmetros
N_SEARCHES = 20
N_ITER_PER_SEARCH = 5
SAMPLE_SIZE = 0.05  # % of training data for hyperparameter search

print(f"Modelo configurado: {MODEL_NAME}")
print(f"Buscas: {N_SEARCHES} x {N_ITER_PER_SEARCH} iterações")
# Out:
# Modelo configurado: XGBoost
# Buscas: 20 x 5 iterações

# %% [markdown]
# ## 2. Carregamento e Preparação dos Dados

# %%
# Carregamento e preparação inicial dos dados
print("=== CARREGAMENTO DOS DATASETS ===")

# Carregar e preparar datasets usando função do módulo
X_train, X_test, y_train, y_test, X_train_scaled, X_test_scaled, train_data, test_data, scaler = load_and_prepare_datasets()

print(f"Dataset de treino: {train_data.shape}")
print(f"Dataset de teste: {test_data.shape}")
print(f"Features: {X_train_scaled.shape[1]}")

print("\nDistribuição das classes:")
print("Treino:", y_train.value_counts().to_dict())
print("Teste:", y_test.value_counts().to_dict())

print("\nPrimeiras linhas do dataset de treino:")
# Out:
# === CARREGAMENTO DOS DATASETS ===
# Dataset de treino: (37233, 1825)
# Dataset de teste: (12411, 1825)
# Features: 1824
#
# Distribuição das classes:
# Treino: {1: 7050, 2: 5577, 3: 4282, 4: 3733, 5: 3430, 7: 2895, 6: 2857, 8: 2537, 0: 2533, 9: 2339}
# Teste: {1: 2430, 2: 1790, 3: 1408, 4: 1257, 5: 1203, 6: 995, 7: 912, 8: 815, 0: 813, 9: 788}
#
# Primeiras linhas do dataset de treino:
# Dataset de treino: (37233, 1825)
# Dataset de teste: (12411, 1825)
# Features: 1824
#
# Distribuição das classes:
# Treino: {1: 7050, 2: 5577, 3: 4282, 4: 3733, 5: 3430, 7: 2895, 6: 2857, 8: 2537, 0: 2533, 9: 2339}
# Teste: {1: 2430, 2: 1790, 3: 1408, 4: 1257, 5: 1203, 6: 995, 7: 912, 8: 815, 0: 813, 9: 788}
#
# Primeiras linhas do dataset de treino:

# %%
train_data.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.132290 -0.078874 -0.007970  0.126206 -0.019496  0.049232  0.118899
# 1 -1.261489 -1.223371 -1.000089 -1.225078 -1.232434 -0.959512 -1.124728
# 2 -0.803139 -0.742865 -0.624391 -0.887569 -0.834537 -0.721469 -0.968023
# 3  0.495477  0.708491  0.804662  0.502907  0.720904  0.816273  0.587815
# 4  0.731854  0.843948  0.588933  0.628960  0.746698  0.552313  0.452046
#
#           7         8         9  ...      1815      1816      1817      1818  \
# 0 -0.035883  0.027992  0.031445  ...  1.514577  1.355709  1.418220  1.314246
# 1 -1.226982 -0.848620 -1.207445  ... -1.251411 -1.451988 -1.167611 -1.313675
# 2 -0.922214 -0.717852 -0.951887  ... -1.567787 -1.773163 -1.590253 -1.399433
# 3  0.800239  0.893713  0.593013  ...  0.951751  0.926661  1.139622  0.921222
# 4  0.575681  0.506712  0.329009  ...  0.918366  0.802927  0.817431  0.947489
#
#        1819      1820      1821      1822      1823  digit
# 0  1.393841  1.382280  1.272189  1.350409  1.342505      1
# 1 -1.466612 -1.229501 -1.268458 -1.301135 -1.067532      1
# 2 -1.590376 -1.392650 -1.309864 -1.443503 -1.416043      1
# 3  0.899732  1.112191  0.930080  0.907232  1.048508      2
# 4  0.807747  0.683944  0.860839  0.730585  0.559723      2
#
# [5 rows x 1825 columns]

# %% [markdown]
# ## 3. Sampling para Busca de Hiperparâmetros

# %%
# ======================================================================
# SAMPLING ESTRATIFICADO PARA BUSCA DE HIPERPARÂMETROS
# ======================================================================

print("=== PREPARAÇÃO DE AMOSTRA PARA BUSCA DE HIPERPARÂMETROS ===")

# Amostra estratificada do dataset de treino
_, X_sample, _, y_sample = train_test_split(
    X_train_scaled, y_train, 
    test_size=SAMPLE_SIZE,  
    stratify=y_train,
    random_state=RANDOM_STATE_SAMPLE
)

print(f"Dataset original de treino: {X_train_scaled.shape[0]:,} amostras")
print(f"Amostra para busca de hiperparâmetros: {X_sample.shape[0]:,} amostras")
print(f"Redução: {(1 - X_sample.shape[0]/X_train_scaled.shape[0])*100:.1f}%")

print("\nDistribuição das classes na amostra:")
print("Amostra:", pd.Series(y_sample).value_counts().to_dict())
print("Original:", y_train.value_counts().to_dict())
# Out:
# === PREPARAÇÃO DE AMOSTRA PARA BUSCA DE HIPERPARÂMETROS ===
# Dataset original de treino: 37,233 amostras
# Amostra para busca de hiperparâmetros: 1,862 amostras
# Redução: 95.0%
#
# Distribuição das classes na amostra:
# Amostra: {1: 352, 2: 279, 3: 214, 4: 187, 5: 171, 7: 145, 6: 143, 0: 127, 8: 127, 9: 117}
# Original: {1: 7050, 2: 5577, 3: 4282, 4: 3733, 5: 3430, 7: 2895, 6: 2857, 8: 2537, 0: 2533, 9: 2339}
# Dataset original de treino: 37,233 amostras
# Amostra para busca de hiperparâmetros: 1,862 amostras
# Redução: 95.0%
#
# Distribuição das classes na amostra:
# Amostra: {1: 352, 2: 279, 3: 214, 4: 187, 5: 171, 7: 145, 6: 143, 0: 127, 8: 127, 9: 117}
# Original: {1: 7050, 2: 5577, 3: 4282, 4: 3733, 5: 3430, 7: 2895, 6: 2857, 8: 2537, 0: 2533, 9: 2339}

# %% [markdown]
# ## 4. Definir Estratégia de Validação Cruzada

# %%
# Usar estratégia de CV padrão dos módulos
print(f"Estratégia de CV: {DEFAULT_CV_STRATEGY}")

# %% [markdown]
# ## 5. XGBoost - Busca de Hiperparâmetros

# %% [markdown]
# ### 5.1 Definir Espaço de Hiperparâmetros

# %%
# ======================================================================
# DEFINIÇÃO DO ESPAÇO DE HIPERPARÂMETROS - OTIMIZADO
# ======================================================================

# Hiperparâmetros otimizados baseados em análise dos melhores resultados:
# - Melhor modelo: F1=0.4203 com lr=0.91, subsample=0.89, max_depth=14
# - Padrão: learning_rate entre 0.9-1.5, subsample >0.8, alta regularização
param_distributions = {
    'n_estimators': randint(100, 250),  # Focado em range médio-alto (melhor: 165-293)
    'max_depth': randint(5, 40),  # Árvores profundas funcionam melhor (melhor: 10-14)
    'learning_rate': uniform(0.7, 1.5),  # Range conservador (melhor: 0.91-1.47)
    'subsample': uniform(0.4, 0.5),  # 0.7-0.95 - CRÍTICO! Melhor resultado usa 0.89
    'colsample_bytree': uniform(0.3, 0.4),  # 0.3-0.8 - melhor entre 0.31-0.63
    'reg_alpha': uniform(1.5, 1.5),  # Alta regularização L1 (melhor: 0.7-2.66)
    'reg_lambda': uniform(2, 2.5),  # Alta regularização L2 (melhor: 0.6-3.49)
    'min_child_weight': randint(4, 20),  # Focado em valores menores (melhor: 4-17)
    'gamma': uniform(0.15, 0.75),  # 0.15-0.9 - redução mínima para split (melhor: 0.15-0.81)
}

# %% [markdown]
# ### 5.2 Executar Busca de Hiperparâmetros

# %%
# ======================================================================
# BUSCA DE HIPERPARAMETROS
# ======================================================================

print(f"=== BUSCA DE HIPERPARÂMETROS - {MODEL_NAME} ===")
print(f"Iniciando busca de hiperparâmetros para {MODEL_NAME}...")
print(f"Executando {N_SEARCHES} buscas com {N_ITER_PER_SEARCH} iterações cada...")
print(f"Usando amostra de {X_sample.shape[0]:,} exemplos\n")

# Múltiplas execuções do RandomizedSearchCV
search, all_searches, best_params = multiple_randomized_search(
    estimator=MODEL_CLASS(
        objective='multi:softprob', 
        num_class=10,              
        eval_metric='mlogloss',     
        random_state=RANDOM_STATE_MODEL,
        n_jobs=-1,
        verbosity=0
    ),
    param_distributions=param_distributions,
    X=X_sample,
    y=y_sample,
    cv_strategy=DEFAULT_CV_STRATEGY,
    n_searches=N_SEARCHES,
    n_iter_per_search=N_ITER_PER_SEARCH,
    scoring=SCORING_METRIC,
    n_jobs=-1
)

# Exibir os melhores resultados
print(f"\n--- RESULTADOS {MODEL_NAME} ---")
print("Melhores hiperparâmetros encontrados:")
for param, value in search.best_params_.items():
    print(f"  {param}: {value}")
print(f"\nMelhor F1-Score (CV): {search.best_score_:.4f}")
print(f"Desvio padrão: {search.cv_results_['std_test_score'][search.best_index_]:.4f}")
# Out:
# === BUSCA DE HIPERPARÂMETROS - XGBoost ===
# Iniciando busca de hiperparâmetros para XGBoost...
# Executando 20 buscas com 2 iterações cada...
# Usando amostra de 1,862 exemplos
#
# Executando 20 buscas com 2 iterações cada...
#
# Busca 1/20...
# Melhor score desta busca: 0.4293
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.6933622824906887), 'gamma': np.float64(0.40453173839439016), 'learning_rate': np.float64(0.8254291305177974), 'max_depth': 17, 'min_child_weight': 14, 'n_estimators': 150, 'reg_alpha': np.float64(2.6273590156735676), 'reg_lambda': np.float64(2.12507963301844), 'subsample': np.float64(0.6026153198981652)}
# Melhor score geral até agora: 0.4293
#
# Busca 2/20...
# Melhor score desta busca: 0.4293
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.6933622824906887), 'gamma': np.float64(0.40453173839439016), 'learning_rate': np.float64(0.8254291305177974), 'max_depth': 17, 'min_child_weight': 14, 'n_estimators': 150, 'reg_alpha': np.float64(2.6273590156735676), 'reg_lambda': np.float64(2.12507963301844), 'subsample': np.float64(0.6026153198981652)}
# Melhor score geral até agora: 0.4293
#
# Busca 2/20...
# Melhor score desta busca: 0.4550
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.5941908082086412), 'gamma': np.float64(0.5978553543222765), 'learning_rate': np.float64(0.7665572105237308), 'max_depth': 10, 'min_child_weight': 7, 'n_estimators': 247, 'reg_alpha': np.float64(2.40246339108252), 'reg_lambda': np.float64(3.5262870078264332), 'subsample': np.float64(0.8237660183857596)}
# Melhor score geral até agora: 0.4550
#
# Busca 3/20...
# Melhor score desta busca: 0.4550
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.5941908082086412), 'gamma': np.float64(0.5978553543222765), 'learning_rate': np.float64(0.7665572105237308), 'max_depth': 10, 'min_child_weight': 7, 'n_estimators': 247, 'reg_alpha': np.float64(2.40246339108252), 'reg_lambda': np.float64(3.5262870078264332), 'subsample': np.float64(0.8237660183857596)}
# Melhor score geral até agora: 0.4550
#
# Busca 3/20...
# Melhor score desta busca: 0.3804
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.48563253361194014), 'gamma': np.float64(0.6006204935734932), 'learning_rate': np.float64(1.451929890735975), 'max_depth': 28, 'min_child_weight': 4, 'n_estimators': 133, 'reg_alpha': np.float64(2.716204838269592), 'reg_lambda': np.float64(2.9911940713716376), 'subsample': np.float64(0.6261308567808754)}
# Melhor score geral até agora: 0.4550
#
# Busca 4/20...
# Melhor score desta busca: 0.3804
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.48563253361194014), 'gamma': np.float64(0.6006204935734932), 'learning_rate': np.float64(1.451929890735975), 'max_depth': 28, 'min_child_weight': 4, 'n_estimators': 133, 'reg_alpha': np.float64(2.716204838269592), 'reg_lambda': np.float64(2.9911940713716376), 'subsample': np.float64(0.6261308567808754)}
# Melhor score geral até agora: 0.4550
#
# Busca 4/20...
# Melhor score desta busca: 0.4507
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.41494525132524696), 'gamma': np.float64(0.28199239957478667), 'learning_rate': np.float64(0.8304847013278768), 'max_depth': 18, 'min_child_weight': 11, 'n_estimators': 200, 'reg_alpha': np.float64(2.509930301999781), 'reg_lambda': np.float64(3.0708937292569054), 'subsample': np.float64(0.8735593689469614)}
# Melhor score geral até agora: 0.4550
#
# Busca 5/20...
# Melhor score desta busca: 0.4507
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.41494525132524696), 'gamma': np.float64(0.28199239957478667), 'learning_rate': np.float64(0.8304847013278768), 'max_depth': 18, 'min_child_weight': 11, 'n_estimators': 200, 'reg_alpha': np.float64(2.509930301999781), 'reg_lambda': np.float64(3.0708937292569054), 'subsample': np.float64(0.8735593689469614)}
# Melhor score geral até agora: 0.4550
#
# Busca 5/20...
# Melhor score desta busca: 0.3617
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.49145830018491266), 'gamma': np.float64(0.7151866881423344), 'learning_rate': np.float64(1.6074487580066779), 'max_depth': 20, 'min_child_weight': 18, 'n_estimators': 155, 'reg_alpha': np.float64(1.8192224142059445), 'reg_lambda': np.float64(2.918078493689303), 'subsample': np.float64(0.6458783679938009)}
# Melhor score geral até agora: 0.4550
#
# Busca 6/20...
# Melhor score desta busca: 0.3617
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.49145830018491266), 'gamma': np.float64(0.7151866881423344), 'learning_rate': np.float64(1.6074487580066779), 'max_depth': 20, 'min_child_weight': 18, 'n_estimators': 155, 'reg_alpha': np.float64(1.8192224142059445), 'reg_lambda': np.float64(2.918078493689303), 'subsample': np.float64(0.6458783679938009)}
# Melhor score geral até agora: 0.4550
#
# Busca 6/20...
# Melhor score desta busca: 0.3647
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.38918295778898826), 'gamma': np.float64(0.810952993956528), 'learning_rate': np.float64(2.009491698835158), 'max_depth': 10, 'min_child_weight': 6, 'n_estimators': 202, 'reg_alpha': np.float64(2.3543572226018377), 'reg_lambda': np.float64(2.6313599836770525), 'subsample': np.float64(0.8620080315308012)}
# Melhor score geral até agora: 0.4550
#
# Busca 7/20...
# Melhor score desta busca: 0.3647
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.38918295778898826), 'gamma': np.float64(0.810952993956528), 'learning_rate': np.float64(2.009491698835158), 'max_depth': 10, 'min_child_weight': 6, 'n_estimators': 202, 'reg_alpha': np.float64(2.3543572226018377), 'reg_lambda': np.float64(2.6313599836770525), 'subsample': np.float64(0.8620080315308012)}
# Melhor score geral até agora: 0.4550
#
# Busca 7/20...
# Melhor score desta busca: 0.3636
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.35639878284451176), 'gamma': np.float64(0.26115816798161384), 'learning_rate': np.float64(1.6308281019878033), 'max_depth': 17, 'min_child_weight': 13, 'n_estimators': 149, 'reg_alpha': np.float64(2.4418795949128227), 'reg_lambda': np.float64(3.4309135644955973), 'subsample': np.float64(0.5109486498270821)}
# Melhor score geral até agora: 0.4550
#
# Busca 8/20...
# Melhor score desta busca: 0.3636
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.35639878284451176), 'gamma': np.float64(0.26115816798161384), 'learning_rate': np.float64(1.6308281019878033), 'max_depth': 17, 'min_child_weight': 13, 'n_estimators': 149, 'reg_alpha': np.float64(2.4418795949128227), 'reg_lambda': np.float64(3.4309135644955973), 'subsample': np.float64(0.5109486498270821)}
# Melhor score geral até agora: 0.4550
#
# Busca 8/20...
# Melhor score desta busca: 0.3761
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.6013302687338542), 'gamma': np.float64(0.574486128745507), 'learning_rate': np.float64(1.76029640135075), 'max_depth': 24, 'min_child_weight': 5, 'n_estimators': 150, 'reg_alpha': np.float64(2.4420976188455015), 'reg_lambda': np.float64(2.809926776207705), 'subsample': np.float64(0.764870847384528)}
# Melhor score geral até agora: 0.4550
#
# Busca 9/20...
# Melhor score desta busca: 0.3761
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.6013302687338542), 'gamma': np.float64(0.574486128745507), 'learning_rate': np.float64(1.76029640135075), 'max_depth': 24, 'min_child_weight': 5, 'n_estimators': 150, 'reg_alpha': np.float64(2.4420976188455015), 'reg_lambda': np.float64(2.809926776207705), 'subsample': np.float64(0.764870847384528)}
# Melhor score geral até agora: 0.4550
#
# Busca 9/20...
# Melhor score desta busca: 0.3698
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.5523597674465587), 'gamma': np.float64(0.8098506198828931), 'learning_rate': np.float64(1.6179891349546374), 'max_depth': 22, 'min_child_weight': 8, 'n_estimators': 118, 'reg_alpha': np.float64(2.1355857609316757), 'reg_lambda': np.float64(3.973459831186021), 'subsample': np.float64(0.49631661126966997)}
# Melhor score geral até agora: 0.4550
#
# Busca 10/20...
# Melhor score desta busca: 0.3698
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.5523597674465587), 'gamma': np.float64(0.8098506198828931), 'learning_rate': np.float64(1.6179891349546374), 'max_depth': 22, 'min_child_weight': 8, 'n_estimators': 118, 'reg_alpha': np.float64(2.1355857609316757), 'reg_lambda': np.float64(3.973459831186021), 'subsample': np.float64(0.49631661126966997)}
# Melhor score geral até agora: 0.4550
#
# Busca 10/20...
# Melhor score desta busca: 0.4586
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.3224526203277628), 'gamma': np.float64(0.4309668634195659), 'learning_rate': np.float64(0.8027207047889606), 'max_depth': 16, 'min_child_weight': 19, 'n_estimators': 184, 'reg_alpha': np.float64(2.1459300664522862), 'reg_lambda': np.float64(2.700132958857523), 'subsample': np.float64(0.8903802607253428)}
# Melhor score geral até agora: 0.4586
#
# Busca 11/20...
# Melhor score desta busca: 0.4586
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.3224526203277628), 'gamma': np.float64(0.4309668634195659), 'learning_rate': np.float64(0.8027207047889606), 'max_depth': 16, 'min_child_weight': 19, 'n_estimators': 184, 'reg_alpha': np.float64(2.1459300664522862), 'reg_lambda': np.float64(2.700132958857523), 'subsample': np.float64(0.8903802607253428)}
# Melhor score geral até agora: 0.4586
#
# Busca 11/20...
# Melhor score desta busca: 0.4427
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.3608027867069513), 'gamma': np.float64(0.615228308893274), 'learning_rate': np.float64(0.9036712711109427), 'max_depth': 11, 'min_child_weight': 7, 'n_estimators': 188, 'reg_alpha': np.float64(2.882835492258446), 'reg_lambda': np.float64(3.004361998491772), 'subsample': np.float64(0.8853988127363155)}
# Melhor score geral até agora: 0.4586
#
# Busca 12/20...
# Melhor score desta busca: 0.4427
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.3608027867069513), 'gamma': np.float64(0.615228308893274), 'learning_rate': np.float64(0.9036712711109427), 'max_depth': 11, 'min_child_weight': 7, 'n_estimators': 188, 'reg_alpha': np.float64(2.882835492258446), 'reg_lambda': np.float64(3.004361998491772), 'subsample': np.float64(0.8853988127363155)}
# Melhor score geral até agora: 0.4586
#
# Busca 12/20...
# Melhor score desta busca: 0.4240
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.4650543558276946), 'gamma': np.float64(0.23146670239498435), 'learning_rate': np.float64(1.1661076777166373), 'max_depth': 26, 'min_child_weight': 17, 'n_estimators': 178, 'reg_alpha': np.float64(2.6786254013103794), 'reg_lambda': np.float64(2.564615397685589), 'subsample': np.float64(0.8718413932254024)}
# Melhor score geral até agora: 0.4586
#
# Busca 13/20...
# Melhor score desta busca: 0.4240
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.4650543558276946), 'gamma': np.float64(0.23146670239498435), 'learning_rate': np.float64(1.1661076777166373), 'max_depth': 26, 'min_child_weight': 17, 'n_estimators': 178, 'reg_alpha': np.float64(2.6786254013103794), 'reg_lambda': np.float64(2.564615397685589), 'subsample': np.float64(0.8718413932254024)}
# Melhor score geral até agora: 0.4586
#
# Busca 13/20...
# Melhor score desta busca: 0.4226
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.6460854272743553), 'gamma': np.float64(0.4430357725649884), 'learning_rate': np.float64(1.0494679966156584), 'max_depth': 28, 'min_child_weight': 9, 'n_estimators': 192, 'reg_alpha': np.float64(1.5069951001900384), 'reg_lambda': np.float64(2.820216133438086), 'subsample': np.float64(0.7835705758603618)}
# Melhor score geral até agora: 0.4586
#
# Busca 14/20...
# Melhor score desta busca: 0.4226
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.6460854272743553), 'gamma': np.float64(0.4430357725649884), 'learning_rate': np.float64(1.0494679966156584), 'max_depth': 28, 'min_child_weight': 9, 'n_estimators': 192, 'reg_alpha': np.float64(1.5069951001900384), 'reg_lambda': np.float64(2.820216133438086), 'subsample': np.float64(0.7835705758603618)}
# Melhor score geral até agora: 0.4586
#
# Busca 14/20...
# Melhor score desta busca: 0.3901
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.6799487474722059), 'gamma': np.float64(0.20142494659564306), 'learning_rate': np.float64(1.634615540206251), 'max_depth': 11, 'min_child_weight': 4, 'n_estimators': 106, 'reg_alpha': np.float64(2.712265759451233), 'reg_lambda': np.float64(3.408731484154888), 'subsample': np.float64(0.8390852050706425)}
# Melhor score geral até agora: 0.4586
#
# Busca 15/20...
# Melhor score desta busca: 0.3901
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.6799487474722059), 'gamma': np.float64(0.20142494659564306), 'learning_rate': np.float64(1.634615540206251), 'max_depth': 11, 'min_child_weight': 4, 'n_estimators': 106, 'reg_alpha': np.float64(2.712265759451233), 'reg_lambda': np.float64(3.408731484154888), 'subsample': np.float64(0.8390852050706425)}
# Melhor score geral até agora: 0.4586
#
# Busca 15/20...
# Melhor score desta busca: 0.4338
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.3252826890054007), 'gamma': np.float64(0.6462343978215084), 'learning_rate': np.float64(1.0702360640365298), 'max_depth': 16, 'min_child_weight': 10, 'n_estimators': 128, 'reg_alpha': np.float64(2.897912204744921), 'reg_lambda': np.float64(3.8403580478388304), 'subsample': np.float64(0.6465314177007904)}
# Melhor score geral até agora: 0.4586
#
# Busca 16/20...
# Melhor score desta busca: 0.4338
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.3252826890054007), 'gamma': np.float64(0.6462343978215084), 'learning_rate': np.float64(1.0702360640365298), 'max_depth': 16, 'min_child_weight': 10, 'n_estimators': 128, 'reg_alpha': np.float64(2.897912204744921), 'reg_lambda': np.float64(3.8403580478388304), 'subsample': np.float64(0.6465314177007904)}
# Melhor score geral até agora: 0.4586
#
# Busca 16/20...
# Melhor score desta busca: 0.3524
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.4471954594605611), 'gamma': np.float64(0.6306578844357497), 'learning_rate': np.float64(2.189591962806958), 'max_depth': 27, 'min_child_weight': 5, 'n_estimators': 126, 'reg_alpha': np.float64(1.8442369760519355), 'reg_lambda': np.float64(1.8572902351302956), 'subsample': np.float64(0.813965109227323)}
# Melhor score geral até agora: 0.4586
#
# Busca 17/20...
# Melhor score desta busca: 0.3524
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.4471954594605611), 'gamma': np.float64(0.6306578844357497), 'learning_rate': np.float64(2.189591962806958), 'max_depth': 27, 'min_child_weight': 5, 'n_estimators': 126, 'reg_alpha': np.float64(1.8442369760519355), 'reg_lambda': np.float64(1.8572902351302956), 'subsample': np.float64(0.813965109227323)}
# Melhor score geral até agora: 0.4586
#
# Busca 17/20...
# Melhor score desta busca: 0.4122
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.5165839425551702), 'gamma': np.float64(0.6053602789515165), 'learning_rate': np.float64(0.9556200736122346), 'max_depth': 17, 'min_child_weight': 9, 'n_estimators': 220, 'reg_alpha': np.float64(2.6133505716555856), 'reg_lambda': np.float64(2.7550464154170733), 'subsample': np.float64(0.6803913939642467)}
# Melhor score geral até agora: 0.4586
#
# Busca 18/20...
# Melhor score desta busca: 0.4122
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.5165839425551702), 'gamma': np.float64(0.6053602789515165), 'learning_rate': np.float64(0.9556200736122346), 'max_depth': 17, 'min_child_weight': 9, 'n_estimators': 220, 'reg_alpha': np.float64(2.6133505716555856), 'reg_lambda': np.float64(2.7550464154170733), 'subsample': np.float64(0.6803913939642467)}
# Melhor score geral até agora: 0.4586
#
# Busca 18/20...
# Melhor score desta busca: 0.4590
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.6299069842936507), 'gamma': np.float64(0.23717146389300567), 'learning_rate': np.float64(1.0162324172475017), 'max_depth': 23, 'min_child_weight': 17, 'n_estimators': 217, 'reg_alpha': np.float64(2.2258068380044134), 'reg_lambda': np.float64(3.6995750307151476), 'subsample': np.float64(0.88901849929901)}
# Melhor score geral até agora: 0.4590
#
# Busca 19/20...
# Melhor score desta busca: 0.4590
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.6299069842936507), 'gamma': np.float64(0.23717146389300567), 'learning_rate': np.float64(1.0162324172475017), 'max_depth': 23, 'min_child_weight': 17, 'n_estimators': 217, 'reg_alpha': np.float64(2.2258068380044134), 'reg_lambda': np.float64(3.6995750307151476), 'subsample': np.float64(0.88901849929901)}
# Melhor score geral até agora: 0.4590
#
# Busca 19/20...
# Melhor score desta busca: 0.3815
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.6893742142156853), 'gamma': np.float64(0.4225021529261884), 'learning_rate': np.float64(1.4274694422446417), 'max_depth': 9, 'min_child_weight': 7, 'n_estimators': 129, 'reg_alpha': np.float64(1.6829372081094358), 'reg_lambda': np.float64(3.375476557980811), 'subsample': np.float64(0.506149210793021)}
# Melhor score geral até agora: 0.4590
#
# Busca 20/20...
# Melhor score desta busca: 0.3815
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.6893742142156853), 'gamma': np.float64(0.4225021529261884), 'learning_rate': np.float64(1.4274694422446417), 'max_depth': 9, 'min_child_weight': 7, 'n_estimators': 129, 'reg_alpha': np.float64(1.6829372081094358), 'reg_lambda': np.float64(3.375476557980811), 'subsample': np.float64(0.506149210793021)}
# Melhor score geral até agora: 0.4590
#
# Busca 20/20...
# Melhor score desta busca: 0.4290
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.4385097510168159), 'gamma': np.float64(0.6218688680411744), 'learning_rate': np.float64(0.999145537111154), 'max_depth': 7, 'min_child_weight': 13, 'n_estimators': 169, 'reg_alpha': np.float64(2.8716066234482307), 'reg_lambda': np.float64(3.313715014447884), 'subsample': np.float64(0.5806265456039481)}
# Melhor score geral até agora: 0.4590
#
# 🎯 Busca completa! Melhor score geral: 0.4590
# Total de configurações testadas: 40
#
# --- RESULTADOS XGBoost ---
# Melhores hiperparâmetros encontrados:
#   colsample_bytree: 0.6299069842936507
#   gamma: 0.23717146389300567
#   learning_rate: 1.0162324172475017
#   max_depth: 23
#   min_child_weight: 17
#   n_estimators: 217
#   reg_alpha: 2.2258068380044134
#   reg_lambda: 3.6995750307151476
#   subsample: 0.88901849929901
#
# Melhor F1-Score (CV): 0.4590
# Desvio padrão: 0.0354
# Melhor score desta busca: 0.4290
# Melhor configuração desta busca: {'colsample_bytree': np.float64(0.4385097510168159), 'gamma': np.float64(0.6218688680411744), 'learning_rate': np.float64(0.999145537111154), 'max_depth': 7, 'min_child_weight': 13, 'n_estimators': 169, 'reg_alpha': np.float64(2.8716066234482307), 'reg_lambda': np.float64(3.313715014447884), 'subsample': np.float64(0.5806265456039481)}
# Melhor score geral até agora: 0.4590
#
# 🎯 Busca completa! Melhor score geral: 0.4590
# Total de configurações testadas: 40
#
# --- RESULTADOS XGBoost ---
# Melhores hiperparâmetros encontrados:
#   colsample_bytree: 0.6299069842936507
#   gamma: 0.23717146389300567
#   learning_rate: 1.0162324172475017
#   max_depth: 23
#   min_child_weight: 17
#   n_estimators: 217
#   reg_alpha: 2.2258068380044134
#   reg_lambda: 3.6995750307151476
#   subsample: 0.88901849929901
#
# Melhor F1-Score (CV): 0.4590
# Desvio padrão: 0.0354

# %% [markdown]
# ### 5.3 Visualizar Histórico da Busca

# %%
# Registro de Desempenho - plotar evolução da busca
plot_search_history(all_searches, search, MODEL_NAME)

# %%
# ======================================================================
# ANÁLISE DAS MELHORES CONFIGURAÇÕES ENCONTRADAS
# ======================================================================

print(f"=== MELHORES CONFIGURAÇÕES ENCONTRADAS POR BUSCA - {MODEL_NAME} ===")

# Extrair os melhores resultados de cada busca
best_configs = []

for i, search_result in enumerate(all_searches):
    config = {
        'Busca': i + 1,
        'F1_Score': search_result['best_score'],
        **search_result['best_params']
    }
    best_configs.append(config)

# Criar DataFrame e exibir top configs
results_df = pd.DataFrame(best_configs)
results_df = results_df.sort_values('F1_Score', ascending=False).round(4)

print(f"\nTop configurações (de {len(results_df)} buscas):")
print(results_df.to_string(index=False))

print(f"\nEstatísticas dos F1-Scores encontrados:")
print(f"  Média: {results_df['F1_Score'].mean():.4f}")
print(f"  Mediana: {results_df['F1_Score'].median():.4f}")
print(f"  Desvio padrão: {results_df['F1_Score'].std():.4f}")
print(f"  Min: {results_df['F1_Score'].min():.4f}")
print(f"  Max: {results_df['F1_Score'].max():.4f}")
# Out:
# === MELHORES CONFIGURAÇÕES ENCONTRADAS POR BUSCA - XGBoost ===
#
# Top configurações (de 20 buscas):
#  Busca  F1_Score  colsample_bytree  gamma  learning_rate  max_depth  min_child_weight  n_estimators  reg_alpha  reg_lambda  subsample
#     18    0.4590            0.6299 0.2372         1.0162         23                17           217     2.2258      3.6996     0.8890
#     10    0.4586            0.3225 0.4310         0.8027         16                19           184     2.1459      2.7001     0.8904
#      2    0.4550            0.5942 0.5979         0.7666         10                 7           247     2.4025      3.5263     0.8238
#      4    0.4507            0.4149 0.2820         0.8305         18                11           200     2.5099      3.0709     0.8736
#     11    0.4427            0.3608 0.6152         0.9037         11                 7           188     2.8828      3.0044     0.8854
#     15    0.4338            0.3253 0.6462         1.0702         16                10           128     2.8979      3.8404     0.6465
#      1    0.4293            0.6934 0.4045         0.8254         17                14           150     2.6274      2.1251     0.6026
#     20    0.4290            0.4385 0.6219         0.9991          7                13           169     2.8716      3.3137     0.5806
#     12    0.4240            0.4651 0.2315         1.1661         26                17           178     2.6786      2.5646     0.8718
#     13    0.4226            0.6461 0.4430         1.0495         28                 9           192     1.5070      2.8202     0.7836
#     17    0.4122            0.5166 0.6054         0.9556         17                 9           220     2.6134      2.7550     0.6804
#     14    0.3901            0.6799 0.2014         1.6346         11                 4           106     2.7123      3.4087     0.8391
#     19    0.3815            0.6894 0.4225         1.4275          9                 7           129     1.6829      3.3755     0.5061
#      3    0.3804            0.4856 0.6006         1.4519         28                 4           133     2.7162      2.9912     0.6261
#      8    0.3761            0.6013 0.5745         1.7603         24                 5           150     2.4421      2.8099     0.7649
#      9    0.3698            0.5524 0.8099         1.6180         22                 8           118     2.1356      3.9735     0.4963
#      6    0.3647            0.3892 0.8110         2.0095         10                 6           202     2.3544      2.6314     0.8620
#      7    0.3636            0.3564 0.2612         1.6308         17                13           149     2.4419      3.4309     0.5109
#      5    0.3617            0.4915 0.7152         1.6074         20                18           155     1.8192      2.9181     0.6459
#     16    0.3524            0.4472 0.6307         2.1896         27                 5           126     1.8442      1.8573     0.8140
#
# Estatísticas dos F1-Scores encontrados:
#   Média: 0.4079
#   Mediana: 0.4174
#   Desvio padrão: 0.0368
#   Min: 0.3524
#   Max: 0.4590

# %% [markdown]
# ## 6. Salvar Resultados de Busca

# %%
search_df = save_search_results(
    model_name=MODEL_NAME,
    model_search=search,
    model_all_searches=all_searches,
    n_searches=N_SEARCHES,
    n_iter_per_search=N_ITER_PER_SEARCH,
    scoring=SCORING_METRIC,
    cv_folds=DEFAULT_CV_STRATEGY.get_n_splits(),
    top_params_columns=param_distributions.keys(),
    searches_folder=SEARCHES_FOLDER
)
# Out:
# === SALVANDO RESULTADOS DA BUSCA - XGBOOST ===
#   ✅ Todos os Resultados salvos: searches\xgboost_all_searches.csv
#   Total de configurações testadas: 40
#   ✅ Resumo salvo: searches\xgboost_search_summary.json
#
# --- ESTATÍSTICAS DA BUSCA XGBOOST ---
# Melhor F1-Score: 0.4590
# Desvio padrão do melhor: 0.0354
# F1-Score médio geral: 0.3872
# F1-Score mínimo: 0.3018
# F1-Score máximo: 0.4590

# %% [markdown]
# ### 6.2 Carregar Resultado de Busca (Opcional)

# %%
loaded_results = load_search_results(MODEL_NAME)

# %%
# Plotar a história da busca a partir dos resultados carregados
plot_search_history_from_loaded(loaded_results, MODEL_NAME)

# %% [markdown]
# ### 6.3 Definir Melhores Params e CV score

# %%
# Definir Melhores Parâmetros para Uso Posterior
if 'loaded_results' in locals():
    best_params = get_best_params_from_saved(MODEL_NAME)
    best_score = loaded_results['summary']['best_overall_score']
    print(f"✅ Usando parâmetros carregados: {best_params}")
    print(f"✅ Melhor F1-Score carregado: {best_score:.4f}")
else:
    best_params = search.best_params_
    best_score = search.best_score_
    print(f"✅ Usando parâmetros da busca atual: {best_params}")
    print(f"✅ Melhor F1-Score da busca atual: {best_score:.4f}")

# %% [markdown]
# ## 7. Treinar Modelo Final e Salvar

# %%
# Treinamento Final com melhores hiperparâmetros
best_model = MODEL_CLASS(
    objective='multi:softprob',  # Multiclasse com probabilidades
    num_class=10,  # 10 classes (dígitos 0-9)
    eval_metric='mlogloss',  # Multi-class log loss
    random_state=RANDOM_STATE_MODEL,
    **best_params
)
best_model.fit(X_train_scaled, y_train)
print(f"\nModelo final {MODEL_NAME} treinado com dataset completo: {best_model}")

# %%
# Save the trained model immediately after training
os.makedirs(MODELS_FOLDER, exist_ok=True)

model_path = os.path.join(MODELS_FOLDER, f'{MODEL_NAME.lower().replace(" ", "_")}_model.joblib')
dump(best_model, model_path)
print(f"✅ Model saved to: {model_path}")

# %% [markdown]
# ## 8. Avaliação Final e Salvamento dos Resultados

# %%
# Carregar modelo (Opcional)
loaded_model = load(os.path.join(MODELS_FOLDER, f'{MODEL_NAME.lower().replace(" ", "_")}_model.joblib'))

# %%
print(f"=== AVALIAÇÃO E SALVAMENTO DOS RESULTADOS - {MODEL_NAME} ===")

# Criar pastas se não existirem
os.makedirs(RESULTS_FOLDER, exist_ok=True)

# Avaliação completa do modelo
print("\nAvaliando performance do modelo...")

# Usar datasets completos para avaliação final
X_train_eval = X_train_scaled
y_train_eval = y_train
X_test_eval = X_test_scaled
y_test_eval = y_test

# Avaliar modelo usando função do módulo
train_metrics, test_metrics, y_test_pred = evaluate_model(
    best_model, X_train_eval, X_test_eval, y_train_eval, y_test_eval, MODEL_NAME
)

# %% [markdown]
# ### 8.3 Save Final Results

# %%
# Plot confusion matrix
cm = confusion_matrix(y_test_eval, y_test_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=True)
plt.title(f'{MODEL_NAME} - Confusion Matrix (Test Set)')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8.2 Visualize Confusion Matrix

# %%
print(classification_report(y_test_eval, y_test_pred, zero_division=0))

# %% [markdown]
# ### 8.1 Classification Report

# %%
# Salvar resultados finais usando função do módulo
model_final_results = save_final_results(
    model_name=MODEL_NAME,
    best_params=best_params,
    best_score=best_score,
    train_metrics=train_metrics,
    test_metrics=test_metrics,
    y_pred=y_test_pred,
    y_test=y_test_eval,
    X_train_scaled=X_train_eval,
    X_test_scaled=X_test_eval,
    results_folder=RESULTS_FOLDER
)

# Mostrar resumo final
print(f"\n--- RESUMO FINAL {MODEL_NAME} ---")
print(f"F1-Score CV: {model_final_results['best_cv_score']:.4f}")
print(f"F1-Score Teste: {test_metrics['f1']:.4f}")
print(f"Acurácia Teste: {test_metrics['accuracy']:.4f}")
print(f"Precisão Teste: {test_metrics['precision']:.4f}")
print(f"Recall Teste: {test_metrics['recall']:.4f}")
print(f"G-Mean Teste: {test_metrics['gmean']:.4f}")

print(f"Resultados salvos em: {RESULTS_FOLDER}/")
print(f"\nAvaliação do {MODEL_NAME} concluída com sucesso!")
