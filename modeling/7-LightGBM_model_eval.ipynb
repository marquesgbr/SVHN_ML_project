# %% [markdown]
# ## 1. Setup

# %% [markdown]
# ### 1.1 Importar Libs

# %%
# Importação das bibliotecas necessárias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import os
import json
import pickle
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, train_test_split
from sklearn.metrics import (classification_report, confusion_matrix, 
                           accuracy_score, precision_score, recall_score, 
                           f1_score, roc_auc_score, roc_curve)
from sklearn.preprocessing import StandardScaler
from scipy.stats import uniform, randint
from joblib import dump, load
import warnings
warnings.filterwarnings('ignore')

# Importar funções dos módulos customizados
from ml_utils import evaluate_model, load_and_prepare_datasets, SCORING_METRIC
from search_utils import (plot_search_history, multiple_randomized_search,
                          plot_search_history_from_loaded, 
                          load_search_results, get_best_params_from_saved,
                          save_search_results, save_final_results, 
                          DEFAULT_CV_STRATEGY, SEARCHES_FOLDER, MODELS_FOLDER, RESULTS_FOLDER)
try:
    import lightgbm as lgb
except:
    print("❌ LightGBM não encontrado. Instale com: pip install lightgbm")

# Configurações de plotagem
plt.rcParams['figure.figsize'] = [12, 8]
sns.set_style("whitegrid")

print("Bibliotecas importadas com sucesso!")
print(f"Pandas: {pd.__version__}")
print(f"NumPy: {np.__version__}")
print(f"Scikit-learn: {sklearn.__version__}")
print(f"LightGBM: {lgb.__version__}")
# Out:
# Bibliotecas importadas com sucesso!
# Pandas: 2.3.3
# NumPy: 2.2.6
# Scikit-learn: 1.7.2
# LightGBM: 4.6.0

# %% [markdown]
# ### 1.2 Configuração do Modelo

# %%
# Configuração do modelo e hiperparâmetros
MODEL_NAME = "LightGBM"
MODEL_CLASS = lgb.LGBMClassifier
RANDOM_STATE_MODEL = 42
RANDOM_STATE_SAMPLE = 10

# Configuração da busca de hiperparâmetros
N_SEARCHES = 20
N_ITER_PER_SEARCH = 20
SAMPLE_SIZE = 0.05  # % of training data for hyperparameter search

print(f"Modelo configurado: {MODEL_NAME}")
print(f"Buscas: {N_SEARCHES} x {N_ITER_PER_SEARCH} iterações")
# Out:
# Modelo configurado: LightGBM
# Buscas: 20 x 20 iterações

# %% [markdown]
# ## 2. Carregamento e Preparação dos Dados

# %%
# Carregamento e preparação inicial dos dados
print("=== CARREGAMENTO DOS DATASETS ===")

# Carregar e preparar datasets usando função do módulo
X_train, X_test, y_train, y_test, X_train_scaled, X_test_scaled, train_data, test_data, scaler = load_and_prepare_datasets()

print(f"Dataset de treino: {train_data.shape}")
print(f"Dataset de teste: {test_data.shape}")
print(f"Features: {X_train_scaled.shape[1]}")

print("\nDistribuição das classes:")
print("Treino:", y_train.value_counts().to_dict())
print("Teste:", y_test.value_counts().to_dict())

print("\nPrimeiras linhas do dataset de treino:")
# Out:
# === CARREGAMENTO DOS DATASETS ===
# Dataset de treino: (37233, 1825)
# Dataset de teste: (12411, 1825)
# Features: 1824
#
# Distribuição das classes:
# Treino: {1: 7050, 2: 5577, 3: 4282, 4: 3733, 5: 3430, 7: 2895, 6: 2857, 8: 2537, 0: 2533, 9: 2339}
# Teste: {1: 2430, 2: 1790, 3: 1408, 4: 1257, 5: 1203, 6: 995, 7: 912, 8: 815, 0: 813, 9: 788}
#
# Primeiras linhas do dataset de treino:

# %%
train_data.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.132290 -0.078874 -0.007970  0.126206 -0.019496  0.049232  0.118899
# 1 -1.261489 -1.223371 -1.000089 -1.225078 -1.232434 -0.959512 -1.124728
# 2 -0.803139 -0.742865 -0.624391 -0.887569 -0.834537 -0.721469 -0.968023
# 3  0.495477  0.708491  0.804662  0.502907  0.720904  0.816273  0.587815
# 4  0.731854  0.843948  0.588933  0.628960  0.746698  0.552313  0.452046
#
#           7         8         9  ...      1815      1816      1817      1818  \
# 0 -0.035883  0.027992  0.031445  ...  1.514577  1.355709  1.418220  1.314246
# 1 -1.226982 -0.848620 -1.207445  ... -1.251411 -1.451988 -1.167611 -1.313675
# 2 -0.922214 -0.717852 -0.951887  ... -1.567787 -1.773163 -1.590253 -1.399433
# 3  0.800239  0.893713  0.593013  ...  0.951751  0.926661  1.139622  0.921222
# 4  0.575681  0.506712  0.329009  ...  0.918366  0.802927  0.817431  0.947489
#
#        1819      1820      1821      1822      1823  digit
# 0  1.393841  1.382280  1.272189  1.350409  1.342505      1
# 1 -1.466612 -1.229501 -1.268458 -1.301135 -1.067532      1
# 2 -1.590376 -1.392650 -1.309864 -1.443503 -1.416043      1
# 3  0.899732  1.112191  0.930080  0.907232  1.048508      2
# 4  0.807747  0.683944  0.860839  0.730585  0.559723      2
#
# [5 rows x 1825 columns]

# %% [markdown]
# ## 3. Sampling para Busca de Hiperparâmetros

# %%
# ======================================================================
# SAMPLING ESTRATIFICADO PARA BUSCA DE HIPERPARÂMETROS
# ======================================================================

print("=== PREPARAÇÃO DE AMOSTRA PARA BUSCA DE HIPERPARÂMETROS ===")

# Amostra estratificada do dataset de treino
_, X_sample, _, y_sample = train_test_split(
    X_train_scaled, y_train, 
    test_size=SAMPLE_SIZE,  
    stratify=y_train,
    random_state=RANDOM_STATE_SAMPLE
)

print(f"Dataset original de treino: {X_train_scaled.shape[0]:,} amostras")
print(f"Amostra para busca de hiperparâmetros: {X_sample.shape[0]:,} amostras")
print(f"Redução: {(1 - X_sample.shape[0]/X_train_scaled.shape[0])*100:.1f}%")

print("\nDistribuição das classes na amostra:")
print("Amostra:", pd.Series(y_sample).value_counts().to_dict())
print("Original:", y_train.value_counts().to_dict())
# Out:
# === PREPARAÇÃO DE AMOSTRA PARA BUSCA DE HIPERPARÂMETROS ===
# Dataset original de treino: 37,233 amostras
# Amostra para busca de hiperparâmetros: 1,862 amostras
# Redução: 95.0%
#
# Distribuição das classes na amostra:
# Amostra: {1: 352, 2: 279, 3: 214, 4: 187, 5: 171, 7: 145, 6: 143, 0: 127, 8: 127, 9: 117}
# Original: {1: 7050, 2: 5577, 3: 4282, 4: 3733, 5: 3430, 7: 2895, 6: 2857, 8: 2537, 0: 2533, 9: 2339}

# %% [markdown]
# ## 4. Definir Estratégia de Validação Cruzada

# %%
# Usar estratégia de CV padrão dos módulos
print(f"Estratégia de CV: {DEFAULT_CV_STRATEGY}")
# Out:
# Estratégia de CV: StratifiedKFold(n_splits=5, random_state=42, shuffle=True)

# %% [markdown]
# ## 5. LightGBM - Busca de Hiperparâmetros

# %% [markdown]
# ### 5.1 Definir Espaço de Hiperparâmetros

# %%
# ======================================================================
# DEFINIÇÃO DO ESPAÇO DE HIPERPARÂMETROS
# ======================================================================

# Definir hiperparâmetros específicos para LightGBM
param_distributions = {
    'n_estimators': randint(30, 150),  # Número de árvores
    'max_depth': randint(10, 30),  # Profundidade máxima das árvores
    'learning_rate': uniform(0.1, 1),  # Taxa de aprendizado
    'num_leaves': randint(50, 200),  # Número de folhas por árvore
    'feature_fraction': uniform(0.1, 0.5),  # Fração de features por árvore
    'bagging_fraction': uniform(0.5, 0.45),  # Fração de amostras para cada árvore
    'bagging_freq': randint(10, 70),  # Frequência de bagging
    'lambda_l1': uniform(0.5, 1.5),  # Regularização L1
    'lambda_l2': uniform(1, 1.5),  # Regularização L2
    'min_child_samples': randint(50, 120),  # Amostras mínimas por folha
    'min_child_weight': randint(4, 22),  # Peso mínimo das folhas
}

# %% [markdown]
# ### 5.2 Executar Busca de Hiperparâmetros

# %%
# ======================================================================
# BUSCA DE HIPERPARAMETROS
# ======================================================================

print(f"=== BUSCA DE HIPERPARÂMETROS - {MODEL_NAME} ===")
print(f"Iniciando busca de hiperparâmetros para {MODEL_NAME}...")
print(f"Executando {N_SEARCHES} buscas com {N_ITER_PER_SEARCH} iterações cada...")
print(f"Usando amostra de {X_sample.shape[0]:,} exemplos\n")

# Múltiplas execuções do RandomizedSearchCV
search, all_searches, best_params = multiple_randomized_search(
    estimator=MODEL_CLASS(
        objective='multiclass',
        num_class=10,
        metric='multi_logloss',
        boosting_type='gbdt',
        random_state=RANDOM_STATE_MODEL,
        n_jobs=-1,
        verbosity=-1
    ),
    param_distributions=param_distributions,
    X=X_sample,
    y=y_sample,
    cv_strategy=DEFAULT_CV_STRATEGY,
    n_searches=N_SEARCHES,
    n_iter_per_search=N_ITER_PER_SEARCH,
    scoring=SCORING_METRIC,
    n_jobs=1
)

# Exibir os melhores resultados
print(f"\n--- RESULTADOS {MODEL_NAME} ---")
print("Melhores hiperparâmetros encontrados:")
for param, value in search.best_params_.items():
    print(f"  {param}: {value}")
print(f"\nMelhor F1-Score (CV): {search.best_score_:.4f}")
print(f"Desvio padrão: {search.cv_results_['std_test_score'][search.best_index_]:.4f}")
# Out:
# === BUSCA DE HIPERPARÂMETROS - LightGBM ===
# Iniciando busca de hiperparâmetros para LightGBM...
# Executando 20 buscas com 20 iterações cada...
# Usando amostra de 1,862 exemplos
#
# Executando 20 buscas com 20 iterações cada...
#
# Busca 1/20...
# Melhor score desta busca: 0.4395
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.6027686743388497), 'bagging_freq': 65, 'feature_fraction': np.float64(0.49183041482172296), 'lambda_l1': np.float64(0.5747320914636438), 'lambda_l2': np.float64(1.0945971831395451), 'learning_rate': np.float64(0.2777579289981196), 'max_depth': 14, 'min_child_samples': 109, 'min_child_weight': 5, 'n_estimators': 74, 'num_leaves': 86}
# Melhor score geral até agora: 0.4395
#
# Busca 2/20...
# Melhor score desta busca: 0.5088
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.8215510070562775), 'bagging_freq': 20, 'feature_fraction': np.float64(0.5112678722476715), 'lambda_l1': np.float64(1.7944884163650112), 'lambda_l2': np.float64(2.1583711047705574), 'learning_rate': np.float64(0.21243463222187678), 'max_depth': 28, 'min_child_samples': 116, 'min_child_weight': 5, 'n_estimators': 113, 'num_leaves': 128}
# Melhor score geral até agora: 0.5088
#
# Busca 3/20...
# Melhor score desta busca: 0.5068
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.8097678103759172), 'bagging_freq': 10, 'feature_fraction': np.float64(0.17769117597260062), 'lambda_l1': np.float64(1.8389854027918153), 'lambda_l2': np.float64(1.319238440615098), 'learning_rate': np.float64(0.1427736769835767), 'max_depth': 21, 'min_child_samples': 75, 'min_child_weight': 10, 'n_estimators': 145, 'num_leaves': 77}
# Melhor score geral até agora: 0.5088
#
# Busca 4/20...
# Melhor score desta busca: 0.5009
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.8809205608657933), 'bagging_freq': 21, 'feature_fraction': np.float64(0.4868685624180865), 'lambda_l1': np.float64(1.2151435503425472), 'lambda_l2': np.float64(1.3560599922326078), 'learning_rate': np.float64(0.18884760411902404), 'max_depth': 19, 'min_child_samples': 85, 'min_child_weight': 7, 'n_estimators': 114, 'num_leaves': 130}
# Melhor score geral até agora: 0.5088
#
# Busca 5/20...
# Melhor score desta busca: 0.4715
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.7649720060322603), 'bagging_freq': 52, 'feature_fraction': np.float64(0.4873642919662263), 'lambda_l1': np.float64(0.5031418139570891), 'lambda_l2': np.float64(1.8097588947023038), 'learning_rate': np.float64(0.13157242007734918), 'max_depth': 24, 'min_child_samples': 92, 'min_child_weight': 9, 'n_estimators': 132, 'num_leaves': 199}
# Melhor score geral até agora: 0.5088
#
# Busca 6/20...
# Melhor score desta busca: 0.5186
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.8388456924508048), 'bagging_freq': 38, 'feature_fraction': np.float64(0.2102927319267783), 'lambda_l1': np.float64(1.9906330000239434), 'lambda_l2': np.float64(2.3207853209513196), 'learning_rate': np.float64(0.17727661494937555), 'max_depth': 16, 'min_child_samples': 100, 'min_child_weight': 4, 'n_estimators': 73, 'num_leaves': 162}
# Melhor score geral até agora: 0.5186
#
# Busca 7/20...
# Melhor score desta busca: 0.4498
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.8277219247211798), 'bagging_freq': 49, 'feature_fraction': np.float64(0.1731375250932247), 'lambda_l1': np.float64(1.2057416252416226), 'lambda_l2': np.float64(1.4794947318516503), 'learning_rate': np.float64(0.6683265808095327), 'max_depth': 10, 'min_child_samples': 86, 'min_child_weight': 6, 'n_estimators': 136, 'num_leaves': 134}
# Melhor score geral até agora: 0.5186
#
# Busca 8/20...
# Melhor score desta busca: 0.4748
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.741439928168018), 'bagging_freq': 13, 'feature_fraction': np.float64(0.16302388187572955), 'lambda_l1': np.float64(0.6568628420730316), 'lambda_l2': np.float64(2.3177608528421065), 'learning_rate': np.float64(0.34198938314638305), 'max_depth': 28, 'min_child_samples': 107, 'min_child_weight': 5, 'n_estimators': 52, 'num_leaves': 73}
# Melhor score geral até agora: 0.5186
#
# Busca 9/20...
# Melhor score desta busca: 0.4854
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.8824991405319941), 'bagging_freq': 35, 'feature_fraction': np.float64(0.275240269701053), 'lambda_l1': np.float64(1.6433734260024606), 'lambda_l2': np.float64(1.5239265275995644), 'learning_rate': np.float64(0.3217700043972961), 'max_depth': 22, 'min_child_samples': 104, 'min_child_weight': 9, 'n_estimators': 124, 'num_leaves': 59}
# Melhor score geral até agora: 0.5186
#
# Busca 10/20...
# Melhor score desta busca: 0.4789
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.7007116349051339), 'bagging_freq': 37, 'feature_fraction': np.float64(0.4636263485732003), 'lambda_l1': np.float64(1.9176070812792156), 'lambda_l2': np.float64(1.623025273064534), 'learning_rate': np.float64(0.19109614352170848), 'max_depth': 14, 'min_child_samples': 71, 'min_child_weight': 6, 'n_estimators': 81, 'num_leaves': 198}
# Melhor score geral até agora: 0.5186
#
# Busca 11/20...
# Melhor score desta busca: 0.4879
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.8384097245731068), 'bagging_freq': 12, 'feature_fraction': np.float64(0.30695295846373305), 'lambda_l1': np.float64(1.217630946527417), 'lambda_l2': np.float64(2.373673740723358), 'learning_rate': np.float64(0.193145978466039), 'max_depth': 23, 'min_child_samples': 115, 'min_child_weight': 9, 'n_estimators': 79, 'num_leaves': 183}
# Melhor score geral até agora: 0.5186
#
# Busca 12/20...
# Melhor score desta busca: 0.4823
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.9098046939025074), 'bagging_freq': 33, 'feature_fraction': np.float64(0.26472292542693776), 'lambda_l1': np.float64(1.2247866056521564), 'lambda_l2': np.float64(2.3876737637658962), 'learning_rate': np.float64(0.2957417993436874), 'max_depth': 18, 'min_child_samples': 115, 'min_child_weight': 9, 'n_estimators': 61, 'num_leaves': 96}
# Melhor score geral até agora: 0.5186
#
# Busca 13/20...
# Melhor score desta busca: 0.4889
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.9121279375512217), 'bagging_freq': 48, 'feature_fraction': np.float64(0.40052586761285747), 'lambda_l1': np.float64(1.6551962144807935), 'lambda_l2': np.float64(1.0503446710255746), 'learning_rate': np.float64(0.3958268873586437), 'max_depth': 17, 'min_child_samples': 84, 'min_child_weight': 5, 'n_estimators': 100, 'num_leaves': 168}
# Melhor score geral até agora: 0.5186
#
# Busca 14/20...
# Melhor score desta busca: 0.4975
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.8468876167687511), 'bagging_freq': 28, 'feature_fraction': np.float64(0.27966532874928185), 'lambda_l1': np.float64(0.865216674880684), 'lambda_l2': np.float64(1.4168832858664997), 'learning_rate': np.float64(0.10781787716826555), 'max_depth': 26, 'min_child_samples': 76, 'min_child_weight': 9, 'n_estimators': 59, 'num_leaves': 181}
# Melhor score geral até agora: 0.5186
#
# Busca 15/20...
# Melhor score desta busca: 0.4565
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.9119711933150816), 'bagging_freq': 27, 'feature_fraction': np.float64(0.2057342783682605), 'lambda_l1': np.float64(1.4709332712657572), 'lambda_l2': np.float64(1.232557903570226), 'learning_rate': np.float64(0.6151985407817608), 'max_depth': 12, 'min_child_samples': 87, 'min_child_weight': 8, 'n_estimators': 81, 'num_leaves': 75}
# Melhor score geral até agora: 0.5186
#
# Busca 16/20...
# Melhor score desta busca: 0.4792
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.8167239018422665), 'bagging_freq': 23, 'feature_fraction': np.float64(0.300404042196575), 'lambda_l1': np.float64(1.3869073721428957), 'lambda_l2': np.float64(2.3380884378802604), 'learning_rate': np.float64(0.5318757234490156), 'max_depth': 13, 'min_child_samples': 115, 'min_child_weight': 4, 'n_estimators': 149, 'num_leaves': 151}
# Melhor score geral até agora: 0.5186
#
# Busca 17/20...
# Melhor score desta busca: 0.4844
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.8650890165693912), 'bagging_freq': 42, 'feature_fraction': np.float64(0.36583424917243146), 'lambda_l1': np.float64(1.1280812069051782), 'lambda_l2': np.float64(1.8509216692546535), 'learning_rate': np.float64(0.32181817755168773), 'max_depth': 15, 'min_child_samples': 87, 'min_child_weight': 5, 'n_estimators': 144, 'num_leaves': 121}
# Melhor score geral até agora: 0.5186
#
# Busca 18/20...
# Melhor score desta busca: 0.5193
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.8849060927721962), 'bagging_freq': 29, 'feature_fraction': np.float64(0.47430927136920875), 'lambda_l1': np.float64(0.8497537548908722), 'lambda_l2': np.float64(1.8488649871290401), 'learning_rate': np.float64(0.2551876985594319), 'max_depth': 27, 'min_child_samples': 107, 'min_child_weight': 4, 'n_estimators': 105, 'num_leaves': 160}
# Melhor score geral até agora: 0.5193
#
# Busca 19/20...
# Melhor score desta busca: 0.5012
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.9499058046593818), 'bagging_freq': 46, 'feature_fraction': np.float64(0.11261532611028566), 'lambda_l1': np.float64(0.6888181070783408), 'lambda_l2': np.float64(2.275150979150595), 'learning_rate': np.float64(0.10286139430554866), 'max_depth': 11, 'min_child_samples': 106, 'min_child_weight': 11, 'n_estimators': 82, 'num_leaves': 67}
# Melhor score geral até agora: 0.5193
#
# Busca 20/20...
# Melhor score desta busca: 0.4757
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.9440949294685422), 'bagging_freq': 10, 'feature_fraction': np.float64(0.1697346874004885), 'lambda_l1': np.float64(1.2449068734231215), 'lambda_l2': np.float64(1.9374140370745343), 'learning_rate': np.float64(0.5056614634271903), 'max_depth': 16, 'min_child_samples': 116, 'min_child_weight': 10, 'n_estimators': 88, 'num_leaves': 92}
# Melhor score geral até agora: 0.5193
#
# 🎯 Busca completa! Melhor score geral: 0.5193
# Total de configurações testadas: 400
#
# --- RESULTADOS LightGBM ---
# Melhores hiperparâmetros encontrados:
#   bagging_fraction: 0.8849060927721962
#   bagging_freq: 29
#   feature_fraction: 0.47430927136920875
#   lambda_l1: 0.8497537548908722
#   lambda_l2: 1.8488649871290401
#   learning_rate: 0.2551876985594319
#   max_depth: 27
#   min_child_samples: 107
#   min_child_weight: 4
#   n_estimators: 105
#   num_leaves: 160
#
# Melhor F1-Score (CV): 0.5193
# Desvio padrão: 0.0290

# %% [markdown]
# ### 5.3 Visualizar Histórico da Busca

# %%
# Registro de Desempenho - plotar evolução da busca
plot_search_history(all_searches, search, MODEL_NAME)

# %%
# ======================================================================
# ANÁLISE DAS MELHORES CONFIGURAÇÕES ENCONTRADAS
# ======================================================================

print(f"=== MELHORES CONFIGURAÇÕES ENCONTRADAS POR BUSCA - {MODEL_NAME} ===")

# Extrair os melhores resultados de cada busca
best_configs = []

for i, search_result in enumerate(all_searches):
    config = {
        'Busca': i + 1,
        'F1_Score': search_result['best_score'],
        **search_result['best_params']
    }
    best_configs.append(config)

# Criar DataFrame e exibir top configs
results_df = pd.DataFrame(best_configs)
results_df = results_df.sort_values('F1_Score', ascending=False).round(4)

print(f"\nTop configurações (de {len(results_df)} buscas):")
print(results_df.to_string(index=False))

print(f"\nEstatísticas dos F1-Scores encontrados:")
print(f"  Média: {results_df['F1_Score'].mean():.4f}")
print(f"  Mediana: {results_df['F1_Score'].median():.4f}")
print(f"  Desvio padrão: {results_df['F1_Score'].std():.4f}")
print(f"  Min: {results_df['F1_Score'].min():.4f}")
print(f"  Max: {results_df['F1_Score'].max():.4f}")
# Out:
# === MELHORES CONFIGURAÇÕES ENCONTRADAS POR BUSCA - LightGBM ===
#
# Top configurações (de 20 buscas):
#  Busca  F1_Score  bagging_fraction  bagging_freq  feature_fraction  lambda_l1  lambda_l2  learning_rate  max_depth  min_child_samples  min_child_weight  n_estimators  num_leaves
#     18    0.5193            0.8849            29            0.4743     0.8498     1.8489         0.2552         27                107                 4           105         160
#      6    0.5186            0.8388            38            0.2103     1.9906     2.3208         0.1773         16                100                 4            73         162
#      2    0.5088            0.8216            20            0.5113     1.7945     2.1584         0.2124         28                116                 5           113         128
#      3    0.5068            0.8098            10            0.1777     1.8390     1.3192         0.1428         21                 75                10           145          77
#     19    0.5012            0.9499            46            0.1126     0.6888     2.2752         0.1029         11                106                11            82          67
#      4    0.5009            0.8809            21            0.4869     1.2151     1.3561         0.1888         19                 85                 7           114         130
#     14    0.4975            0.8469            28            0.2797     0.8652     1.4169         0.1078         26                 76                 9            59         181
#     13    0.4889            0.9121            48            0.4005     1.6552     1.0503         0.3958         17                 84                 5           100         168
#     11    0.4879            0.8384            12            0.3070     1.2176     2.3737         0.1931         23                115                 9            79         183
#      9    0.4854            0.8825            35            0.2752     1.6434     1.5239         0.3218         22                104                 9           124          59
#     17    0.4844            0.8651            42            0.3658     1.1281     1.8509         0.3218         15                 87                 5           144         121
#     12    0.4823            0.9098            33            0.2647     1.2248     2.3877         0.2957         18                115                 9            61          96
#     16    0.4792            0.8167            23            0.3004     1.3869     2.3381         0.5319         13                115                 4           149         151
#     10    0.4789            0.7007            37            0.4636     1.9176     1.6230         0.1911         14                 71                 6            81         198
#     20    0.4757            0.9441            10            0.1697     1.2449     1.9374         0.5057         16                116                10            88          92
#      8    0.4748            0.7414            13            0.1630     0.6569     2.3178         0.3420         28                107                 5            52          73
#      5    0.4715            0.7650            52            0.4874     0.5031     1.8098         0.1316         24                 92                 9           132         199
#     15    0.4565            0.9120            27            0.2057     1.4709     1.2326         0.6152         12                 87                 8            81          75
#      7    0.4498            0.8277            49            0.1731     1.2057     1.4795         0.6683         10                 86                 6           136         134
#      1    0.4395            0.6028            65            0.4918     0.5747     1.0946         0.2778         14                109                 5            74          86
#
# Estatísticas dos F1-Scores encontrados:
#   Média: 0.4854
#   Mediana: 0.4849
#   Desvio padrão: 0.0213
#   Min: 0.4395
#   Max: 0.5193

# %% [markdown]
# ## 6. Salvar Resultados de Busca

# %%
search_df = save_search_results(
    model_name=MODEL_NAME,
    model_search=search,
    model_all_searches=all_searches,
    n_searches=N_SEARCHES,
    n_iter_per_search=N_ITER_PER_SEARCH,
    scoring=SCORING_METRIC,
    cv_folds=DEFAULT_CV_STRATEGY.get_n_splits(),
    top_params_columns=param_distributions.keys(),
    searches_folder=SEARCHES_FOLDER
)
# Out:
# === SALVANDO RESULTADOS DA BUSCA - LIGHTGBM ===
#   ✅ Todos os Resultados salvos: searches\lightgbm_all_searches.csv
#   Total de configurações testadas: 400
#   ✅ Resumo salvo: searches\lightgbm_search_summary.json
#
# --- ESTATÍSTICAS DA BUSCA LIGHTGBM ---
# Melhor F1-Score: 0.5193
# Desvio padrão do melhor: 0.0290
# F1-Score médio geral: 0.3932
# F1-Score mínimo: 0.2390
# F1-Score máximo: 0.5193

# %% [markdown]
# ### 6.2 Carregar Resultado de Busca (Opcional)

# %%
loaded_results = load_search_results(MODEL_NAME)
# Out:
# === CARREGANDO RESULTADOS DE BUSCA - LIGHTGBM ===
# ✅ Resultados detalhados carregados: 400 configurações
# ✅ Resumo carregado: F1-Score = 0.5193

# %%
# Plotar a história da busca a partir dos resultados carregados
plot_search_history_from_loaded(loaded_results, MODEL_NAME)

# %% [markdown]
# ### 6.3 Definir Melhores Params e CV score

# %%
# Definir Melhores Parâmetros para Uso Posterior
if 'loaded_results' in locals():
    best_params = get_best_params_from_saved(MODEL_NAME)
    best_score = loaded_results['summary']['best_overall_score']
    print(f"✅ Usando parâmetros carregados: {best_params}")
    print(f"✅ Melhor F1-Score carregado: {best_score:.4f}")
else:
    best_params = search.best_params_
    best_score = search.best_score_
    print(f"✅ Usando parâmetros da busca atual: {best_params}")
    print(f"✅ Melhor F1-Score da busca atual: {best_score:.4f}")
# Out:
# ✅ Usando parâmetros carregados: {'bagging_fraction': 0.8849060927721962, 'bagging_freq': 29, 'feature_fraction': 0.47430927136920875, 'lambda_l1': 0.8497537548908722, 'lambda_l2': 1.8488649871290401, 'learning_rate': 0.2551876985594319, 'max_depth': 27, 'min_child_samples': 107, 'min_child_weight': 4, 'n_estimators': 105, 'num_leaves': 160}
# ✅ Melhor F1-Score carregado: 0.5193

# %% [markdown]
# ## 7. Treinar Modelo Final e Salvar

# %%
# Treinamento Final com melhores hiperparâmetros

best_model = MODEL_CLASS(random_state=RANDOM_STATE_MODEL, **best_params)
best_model.fit(X_train_scaled, y_train)
print(f"\nModelo final {MODEL_NAME} treinado com dataset completo: {best_model}")
# Out:
# Modelo final LightGBM treinado com dataset completo: LGBMClassifier(bagging_fraction=0.8849060927721962, bagging_freq=29,
#                feature_fraction=0.47430927136920875,
#                lambda_l1=0.8497537548908722, lambda_l2=1.8488649871290401,
#                learning_rate=0.2551876985594319, max_depth=27,
#                min_child_samples=107, min_child_weight=4, n_estimators=105,
#                num_leaves=160, random_state=42)

# %%
# Save the trained model immediately after training
os.makedirs(MODELS_FOLDER, exist_ok=True)

model_path = os.path.join(MODELS_FOLDER, f'{MODEL_NAME.lower().replace(" ", "_")}_model.joblib')
dump(best_model, model_path)
print(f"✅ Model saved to: {model_path}")
# Out:
# ✅ Model saved to: models\lightgbm_model.joblib

# %% [markdown]
# ## 8. Avaliação Final e Salvamento dos Resultados

# %%
# Carregar modelo (Opcional)
loaded_model = load(os.path.join(MODELS_FOLDER, f'{MODEL_NAME.lower().replace(" ", "_")}_model.joblib'))

# %%
print(f"=== AVALIAÇÃO E SALVAMENTO DOS RESULTADOS - {MODEL_NAME} ===")

# Criar pastas se não existirem
os.makedirs(RESULTS_FOLDER, exist_ok=True)

# Avaliação completa do modelo
print("\nAvaliando performance do modelo...")

# Usar datasets completos para avaliação final
X_train_eval = X_train_scaled
y_train_eval = y_train
X_test_eval = X_test_scaled
y_test_eval = y_test

# Avaliar modelo usando função do módulo
train_metrics, test_metrics, y_test_pred = evaluate_model(
    best_model, X_train_eval, X_test_eval, y_train_eval, y_test_eval, MODEL_NAME
)
# Out:
# === AVALIAÇÃO E SALVAMENTO DOS RESULTADOS - LightGBM ===
#
# Avaliando performance do modelo...

# %% [markdown]
# ### 8.1 Classification Report

# %%
print(classification_report(y_test_eval, y_test_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80       813
#            1       0.84      0.91      0.87      2430
#            2       0.83      0.88      0.85      1790
#            3       0.79      0.77      0.78      1408
#            4       0.84      0.83      0.84      1257
#            5       0.80      0.81      0.80      1203
#            6       0.78      0.71      0.75       995
#            7       0.84      0.81      0.83       912
#            8       0.77      0.67      0.71       815
#            9       0.78      0.73      0.76       788
#
#     accuracy                           0.81     12411
#    macro avg       0.81      0.79      0.80     12411
# weighted avg       0.81      0.81      0.81     12411

# %% [markdown]
# ### 8.2 Visualize Confusion Matrix

# %%
# Plot confusion matrix
cm = confusion_matrix(y_test_eval, y_test_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=True)
plt.title(f'{MODEL_NAME} - Confusion Matrix (Test Set)')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8.3 Save Final Results

# %%
# Salvar resultados finais usando função do módulo
model_final_results = save_final_results(
    model_name=MODEL_NAME,
    best_params=best_params,
    best_score=best_score,
    train_metrics=train_metrics,
    test_metrics=test_metrics,
    y_pred=y_test_pred,
    y_test=y_test_eval,
    X_train_scaled=X_train_eval,
    X_test_scaled=X_test_eval,
    results_folder=RESULTS_FOLDER
)

# Mostrar resumo final
print(f"\n--- RESUMO FINAL {MODEL_NAME} ---")
print(f"F1-Score CV: {model_final_results['best_cv_score']:.4f}")
print(f"F1-Score Teste: {test_metrics['f1']:.4f}")
print(f"Acurácia Teste: {test_metrics['accuracy']:.4f}")
print(f"Precisão Teste: {test_metrics['precision']:.4f}")
print(f"Recall Teste: {test_metrics['recall']:.4f}")
print(f"G-Mean Teste: {test_metrics['gmean']:.4f}")

print(f"Resultados salvos em: {RESULTS_FOLDER}/")
print(f"\nAvaliação do {MODEL_NAME} concluída com sucesso!")
# Out:
# ✅ Resultados LightGBM salvos em: results\lightgbm_results.json
#
# --- RESUMO FINAL LightGBM ---
# F1-Score CV: 0.5193
# F1-Score Teste: 0.7989
# Acurácia Teste: 0.8141
# Precisão Teste: 0.8073
# Recall Teste: 0.7923
# G-Mean Teste: 0.7892
# Resultados salvos em: results/
#
# Avaliação do LightGBM concluída com sucesso!
