# %% [markdown]
# ## 1. Setup

# %% [markdown]
# ### 1.1 Importar Libs

# %%
# Importação das bibliotecas necessárias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import os
import json
import pickle
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, train_test_split
from sklearn.metrics import (classification_report, confusion_matrix, 
                           accuracy_score, precision_score, recall_score, 
                           f1_score, roc_auc_score, roc_curve)
from sklearn.preprocessing import StandardScaler
from scipy.stats import uniform, randint
from joblib import dump, load
import warnings
warnings.filterwarnings('ignore')

# Importar funções dos módulos customizados
from ml_utils import evaluate_model, load_and_prepare_datasets, SCORING_METRIC
from search_utils import (plot_search_history, multiple_randomized_search,
                          plot_search_history_from_loaded, 
                          load_search_results, get_best_params_from_saved,
                          save_search_results, save_final_results, 
                          DEFAULT_CV_STRATEGY, SEARCHES_FOLDER, MODELS_FOLDER, RESULTS_FOLDER)
try:
    import lightgbm as lgb
except:
    print("❌ LightGBM não encontrado. Instale com: pip install lightgbm")

# Configurações de plotagem
plt.rcParams['figure.figsize'] = [12, 8]
sns.set_style("whitegrid")

print("Bibliotecas importadas com sucesso!")
print(f"Pandas: {pd.__version__}")
print(f"NumPy: {np.__version__}")
print(f"Scikit-learn: {sklearn.__version__}")
print(f"LightGBM: {lgb.__version__}")
# Out:
# Bibliotecas importadas com sucesso!
# Pandas: 2.3.3
# NumPy: 2.3.5
# Scikit-learn: 1.7.2
# LightGBM: 4.6.0

# %% [markdown]
# ### 1.2 Configuração do Modelo

# %%
# Configuração do modelo e hiperparâmetros
MODEL_NAME = "LightGBM"
MODEL_CLASS = lgb.LGBMClassifier
RANDOM_STATE_MODEL = 42
RANDOM_STATE_SAMPLE = 10

# Configuração da busca de hiperparâmetros
N_SEARCHES = 20
N_ITER_PER_SEARCH = 20
SAMPLE_SIZE = 0.05  # % of training data for hyperparameter search

print(f"Modelo configurado: {MODEL_NAME}")
print(f"Buscas: {N_SEARCHES} x {N_ITER_PER_SEARCH} iterações")
# Out:
# Modelo configurado: LightGBM
# Buscas: 20 x 20 iterações

# %% [markdown]
# ## 2. Carregamento e Preparação dos Dados

# %%
# Carregamento e preparação inicial dos dados
print("=== CARREGAMENTO DOS DATASETS ===")

# Carregar e preparar datasets usando função do módulo
X_train, X_test, y_train, y_test, X_train_scaled, X_test_scaled, train_data, test_data, scaler = load_and_prepare_datasets()

print(f"Dataset de treino: {train_data.shape}")
print(f"Dataset de teste: {test_data.shape}")
print(f"Features: {X_train_scaled.shape[1]}")

print("\nDistribuição das classes:")
print("Treino:", y_train.value_counts().to_dict())
print("Teste:", y_test.value_counts().to_dict())

print("\nPrimeiras linhas do dataset de treino:")
# Out:
# === CARREGAMENTO DOS DATASETS ===
# Dataset de treino: (37233, 1825)
# Dataset de teste: (12411, 1825)
# Features: 1824
#
# Distribuição das classes:
# Treino: {1: 7050, 2: 5577, 3: 4282, 4: 3733, 5: 3430, 7: 2895, 6: 2857, 8: 2537, 0: 2533, 9: 2339}
# Teste: {1: 2430, 2: 1790, 3: 1408, 4: 1257, 5: 1203, 6: 995, 7: 912, 8: 815, 0: 813, 9: 788}
#
# Primeiras linhas do dataset de treino:

# %%
train_data.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.132290 -0.078874 -0.007970  0.126206 -0.019496  0.049232  0.118899
# 1 -1.261489 -1.223371 -1.000089 -1.225078 -1.232434 -0.959512 -1.124728
# 2 -0.803139 -0.742865 -0.624391 -0.887569 -0.834537 -0.721469 -0.968023
# 3  0.495477  0.708491  0.804662  0.502907  0.720904  0.816273  0.587815
# 4  0.731854  0.843948  0.588933  0.628960  0.746698  0.552313  0.452046
#
#           7         8         9  ...      1815      1816      1817      1818  \
# 0 -0.035883  0.027992  0.031445  ...  1.514577  1.355709  1.418220  1.314246
# 1 -1.226982 -0.848620 -1.207445  ... -1.251411 -1.451988 -1.167611 -1.313675
# 2 -0.922214 -0.717852 -0.951887  ... -1.567787 -1.773163 -1.590253 -1.399433
# 3  0.800239  0.893713  0.593013  ...  0.951751  0.926661  1.139622  0.921222
# 4  0.575681  0.506712  0.329009  ...  0.918366  0.802927  0.817431  0.947489
#
#        1819      1820      1821      1822      1823  digit
# 0  1.393841  1.382280  1.272189  1.350409  1.342505      1
# 1 -1.466612 -1.229501 -1.268458 -1.301135 -1.067532      1
# 2 -1.590376 -1.392650 -1.309864 -1.443503 -1.416043      1
# 3  0.899732  1.112191  0.930080  0.907232  1.048508      2
# 4  0.807747  0.683944  0.860839  0.730585  0.559723      2
#
# [5 rows x 1825 columns]

# %% [markdown]
# ## 3. Sampling para Busca de Hiperparâmetros

# %%
# ======================================================================
# SAMPLING ESTRATIFICADO PARA BUSCA DE HIPERPARÂMETROS
# ======================================================================

print("=== PREPARAÇÃO DE AMOSTRA PARA BUSCA DE HIPERPARÂMETROS ===")

# Amostra estratificada do dataset de treino
_, X_sample, _, y_sample = train_test_split(
    X_train_scaled, y_train, 
    test_size=SAMPLE_SIZE,  
    stratify=y_train,
    random_state=RANDOM_STATE_SAMPLE
)

print(f"Dataset original de treino: {X_train_scaled.shape[0]:,} amostras")
print(f"Amostra para busca de hiperparâmetros: {X_sample.shape[0]:,} amostras")
print(f"Redução: {(1 - X_sample.shape[0]/X_train_scaled.shape[0])*100:.1f}%")

print("\nDistribuição das classes na amostra:")
print("Amostra:", pd.Series(y_sample).value_counts().to_dict())
print("Original:", y_train.value_counts().to_dict())
# Out:
# === PREPARAÇÃO DE AMOSTRA PARA BUSCA DE HIPERPARÂMETROS ===
# Dataset original de treino: 37,233 amostras
# Amostra para busca de hiperparâmetros: 1,862 amostras
# Redução: 95.0%
#
# Distribuição das classes na amostra:
# Amostra: {1: 352, 2: 279, 3: 214, 4: 187, 5: 171, 7: 145, 6: 143, 0: 127, 8: 127, 9: 117}
# Original: {1: 7050, 2: 5577, 3: 4282, 4: 3733, 5: 3430, 7: 2895, 6: 2857, 8: 2537, 0: 2533, 9: 2339}
# Dataset original de treino: 37,233 amostras
# Amostra para busca de hiperparâmetros: 1,862 amostras
# Redução: 95.0%
#
# Distribuição das classes na amostra:
# Amostra: {1: 352, 2: 279, 3: 214, 4: 187, 5: 171, 7: 145, 6: 143, 0: 127, 8: 127, 9: 117}
# Original: {1: 7050, 2: 5577, 3: 4282, 4: 3733, 5: 3430, 7: 2895, 6: 2857, 8: 2537, 0: 2533, 9: 2339}

# %% [markdown]
# ## 4. Definir Estratégia de Validação Cruzada

# %%
# Usar estratégia de CV padrão dos módulos
print(f"Estratégia de CV: {DEFAULT_CV_STRATEGY}")

# %% [markdown]
# ## 5. LightGBM - Busca de Hiperparâmetros

# %% [markdown]
# ### 5.1 Definir Espaço de Hiperparâmetros

# %%
# ======================================================================
# DEFINIÇÃO DO ESPAÇO DE HIPERPARÂMETROS
# ======================================================================

# Definir hiperparâmetros específicos para LightGBM
param_distributions = {
    'n_estimators': randint(30, 150),  # Número de árvores
    'max_depth': randint(10, 30),  # Profundidade máxima das árvores
    'learning_rate': uniform(0.1, 1),  # Taxa de aprendizado
    'num_leaves': randint(50, 200),  # Número de folhas por árvore
    'feature_fraction': uniform(0.1, 0.5),  # Fração de features por árvore
    'bagging_fraction': uniform(0.5, 0.45),  # Fração de amostras para cada árvore
    'bagging_freq': randint(10, 70),  # Frequência de bagging
    'lambda_l1': uniform(0.5, 1.5),  # Regularização L1
    'lambda_l2': uniform(1, 1.5),  # Regularização L2
    'min_child_samples': randint(50, 120),  # Amostras mínimas por folha
    'min_child_weight': randint(4, 22),  # Peso mínimo das folhas
}

# %% [markdown]
# ### 5.2 Executar Busca de Hiperparâmetros

# %%
# ======================================================================
# BUSCA DE HIPERPARAMETROS
# ======================================================================

print(f"=== BUSCA DE HIPERPARÂMETROS - {MODEL_NAME} ===")
print(f"Iniciando busca de hiperparâmetros para {MODEL_NAME}...")
print(f"Executando {N_SEARCHES} buscas com {N_ITER_PER_SEARCH} iterações cada...")
print(f"Usando amostra de {X_sample.shape[0]:,} exemplos\n")

# Múltiplas execuções do RandomizedSearchCV
search, all_searches, best_params = multiple_randomized_search(
    estimator=MODEL_CLASS(
        objective='multiclass',
        num_class=10,
        metric='multi_logloss',
        boosting_type='gbdt',
        random_state=RANDOM_STATE_MODEL,
        n_jobs=-1,
        verbosity=-1
    ),
    param_distributions=param_distributions,
    X=X_sample,
    y=y_sample,
    cv_strategy=DEFAULT_CV_STRATEGY,
    n_searches=N_SEARCHES,
    n_iter_per_search=N_ITER_PER_SEARCH,
    scoring=SCORING_METRIC,
    n_jobs=-1
)

# Exibir os melhores resultados
print(f"\n--- RESULTADOS {MODEL_NAME} ---")
print("Melhores hiperparâmetros encontrados:")
for param, value in search.best_params_.items():
    print(f"  {param}: {value}")
print(f"\nMelhor F1-Score (CV): {search.best_score_:.4f}")
print(f"Desvio padrão: {search.cv_results_['std_test_score'][search.best_index_]:.4f}")
# Out:
# === BUSCA DE HIPERPARÂMETROS - LightGBM ===
# Iniciando busca de hiperparâmetros para LightGBM...
# Executando 20 buscas com 20 iterações cada...
# Usando amostra de 1,862 exemplos
#
# Executando 20 buscas com 20 iterações cada...
#
# Busca 1/20...
# Melhor score desta busca: 0.4721
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.7265661202970713), 'bagging_freq': 48, 'feature_fraction': np.float64(0.3111025596728191), 'lambda_l1': np.float64(1.8784694223092862), 'lambda_l2': np.float64(1.4709695672690886), 'learning_rate': np.float64(0.12836583782897695), 'max_depth': 29, 'min_child_samples': 59, 'min_child_weight': 10, 'n_estimators': 104, 'num_leaves': 168}
# Melhor score geral até agora: 0.4721
#
# Busca 2/20...
# Melhor score desta busca: 0.5170
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.9357238938868393), 'bagging_freq': 57, 'feature_fraction': np.float64(0.504709868984816), 'lambda_l1': np.float64(1.7704041573665519), 'lambda_l2': np.float64(2.4411952289519414), 'learning_rate': np.float64(0.14966297367978945), 'max_depth': 14, 'min_child_samples': 106, 'min_child_weight': 7, 'n_estimators': 149, 'num_leaves': 118}
# Melhor score geral até agora: 0.5170
#
# Busca 3/20...
# Melhor score desta busca: 0.5006
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.9297918434233696), 'bagging_freq': 21, 'feature_fraction': np.float64(0.5497445007338726), 'lambda_l1': np.float64(1.6804167819634461), 'lambda_l2': np.float64(1.4398568043459237), 'learning_rate': np.float64(0.2671075738086446), 'max_depth': 15, 'min_child_samples': 104, 'min_child_weight': 4, 'n_estimators': 54, 'num_leaves': 122}
# Melhor score geral até agora: 0.5170
#
# Busca 4/20...
# Melhor score desta busca: 0.4989
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.8891245466057367), 'bagging_freq': 50, 'feature_fraction': np.float64(0.5009029712795797), 'lambda_l1': np.float64(1.8874992908217854), 'lambda_l2': np.float64(1.123616404202496), 'learning_rate': np.float64(0.35359487508967635), 'max_depth': 17, 'min_child_samples': 83, 'min_child_weight': 4, 'n_estimators': 137, 'num_leaves': 182}
# Melhor score geral até agora: 0.5170
#
# Busca 5/20...
# Melhor score desta busca: 0.4931
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.740306104704329), 'bagging_freq': 29, 'feature_fraction': np.float64(0.5457187914724148), 'lambda_l1': np.float64(0.6274202341958198), 'lambda_l2': np.float64(1.6241021168376482), 'learning_rate': np.float64(0.13205164443233156), 'max_depth': 15, 'min_child_samples': 106, 'min_child_weight': 7, 'n_estimators': 136, 'num_leaves': 165}
# Melhor score geral até agora: 0.5170
#
# Busca 6/20...
# Melhor score desta busca: 0.5043
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.9402691001135837), 'bagging_freq': 58, 'feature_fraction': np.float64(0.13677333811154843), 'lambda_l1': np.float64(1.8274865132236864), 'lambda_l2': np.float64(1.7019387054658863), 'learning_rate': np.float64(0.25481566453064153), 'max_depth': 15, 'min_child_samples': 51, 'min_child_weight': 8, 'n_estimators': 78, 'num_leaves': 154}
# Melhor score geral até agora: 0.5170
#
# Busca 7/20...
# Melhor score desta busca: 0.4734
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.6587279010575025), 'bagging_freq': 53, 'feature_fraction': np.float64(0.23707004716383281), 'lambda_l1': np.float64(1.1592571377252003), 'lambda_l2': np.float64(2.387226844307781), 'learning_rate': np.float64(0.10303588668532374), 'max_depth': 11, 'min_child_samples': 58, 'min_child_weight': 7, 'n_estimators': 104, 'num_leaves': 58}
# Melhor score geral até agora: 0.5170
#
# Busca 8/20...
# Melhor score desta busca: 0.5008
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.8671833472517927), 'bagging_freq': 12, 'feature_fraction': np.float64(0.4670553154405065), 'lambda_l1': np.float64(0.976563019847704), 'lambda_l2': np.float64(2.4536228936078226), 'learning_rate': np.float64(0.256042833708629), 'max_depth': 20, 'min_child_samples': 109, 'min_child_weight': 5, 'n_estimators': 101, 'num_leaves': 121}
# Melhor score geral até agora: 0.5170
#
# Busca 9/20...
# Melhor score desta busca: 0.5174
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.9128716758600393), 'bagging_freq': 44, 'feature_fraction': np.float64(0.15845555719279772), 'lambda_l1': np.float64(1.9002334447518419), 'lambda_l2': np.float64(2.0474180801780326), 'learning_rate': np.float64(0.17879323488420576), 'max_depth': 29, 'min_child_samples': 73, 'min_child_weight': 6, 'n_estimators': 70, 'num_leaves': 163}
# Melhor score geral até agora: 0.5174
#
# Busca 10/20...
# Melhor score desta busca: 0.4829
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.9242040926354385), 'bagging_freq': 27, 'feature_fraction': np.float64(0.5430776047085898), 'lambda_l1': np.float64(0.5161593196440215), 'lambda_l2': np.float64(2.3893721124663356), 'learning_rate': np.float64(0.3069925766230609), 'max_depth': 23, 'min_child_samples': 89, 'min_child_weight': 9, 'n_estimators': 111, 'num_leaves': 176}
# Melhor score geral até agora: 0.5174
#
# Busca 11/20...
# Melhor score desta busca: 0.4703
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.8272966883944154), 'bagging_freq': 69, 'feature_fraction': np.float64(0.5901999091443827), 'lambda_l1': np.float64(0.8423727630432907), 'lambda_l2': np.float64(1.5809749975461402), 'learning_rate': np.float64(0.3463905375090247), 'max_depth': 18, 'min_child_samples': 95, 'min_child_weight': 6, 'n_estimators': 44, 'num_leaves': 176}
# Melhor score geral até agora: 0.5174
#
# Busca 12/20...
# Melhor score desta busca: 0.4577
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.8343108821218015), 'bagging_freq': 23, 'feature_fraction': np.float64(0.4646928935130241), 'lambda_l1': np.float64(0.7900525683577551), 'lambda_l2': np.float64(2.2489063622166463), 'learning_rate': np.float64(0.14467060813071278), 'max_depth': 29, 'min_child_samples': 89, 'min_child_weight': 15, 'n_estimators': 95, 'num_leaves': 125}
# Melhor score geral até agora: 0.5174
#
# Busca 13/20...
# Melhor score desta busca: 0.4985
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.8300361385494948), 'bagging_freq': 42, 'feature_fraction': np.float64(0.5964969717625683), 'lambda_l1': np.float64(1.8428834628624566), 'lambda_l2': np.float64(2.4750997847027065), 'learning_rate': np.float64(0.16775792730815256), 'max_depth': 16, 'min_child_samples': 118, 'min_child_weight': 6, 'n_estimators': 59, 'num_leaves': 65}
# Melhor score geral até agora: 0.5174
#
# Busca 14/20...
# Melhor score desta busca: 0.4704
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.8934537254354744), 'bagging_freq': 40, 'feature_fraction': np.float64(0.18055828096049673), 'lambda_l1': np.float64(0.7183262047086849), 'lambda_l2': np.float64(2.216350514914946), 'learning_rate': np.float64(0.5053511673416969), 'max_depth': 27, 'min_child_samples': 74, 'min_child_weight': 6, 'n_estimators': 36, 'num_leaves': 128}
# Melhor score geral até agora: 0.5174
#
# Busca 15/20...
# Melhor score desta busca: 0.5090
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.8510365968062663), 'bagging_freq': 49, 'feature_fraction': np.float64(0.5033780524187201), 'lambda_l1': np.float64(1.3051704092314922), 'lambda_l2': np.float64(1.9416468963107811), 'learning_rate': np.float64(0.22596440819837652), 'max_depth': 20, 'min_child_samples': 82, 'min_child_weight': 4, 'n_estimators': 129, 'num_leaves': 127}
# Melhor score geral até agora: 0.5174
#
# Busca 16/20...
# Melhor score desta busca: 0.4831
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.9238056267317554), 'bagging_freq': 46, 'feature_fraction': np.float64(0.37598659351072894), 'lambda_l1': np.float64(1.919629505809159), 'lambda_l2': np.float64(1.0973595170363537), 'learning_rate': np.float64(0.26641784227022425), 'max_depth': 21, 'min_child_samples': 88, 'min_child_weight': 9, 'n_estimators': 147, 'num_leaves': 129}
# Melhor score geral até agora: 0.5174
#
# Busca 17/20...
# Melhor score desta busca: 0.4699
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.8995170764064999), 'bagging_freq': 68, 'feature_fraction': np.float64(0.5607415787397702), 'lambda_l1': np.float64(1.1938800913849001), 'lambda_l2': np.float64(2.284545490347565), 'learning_rate': np.float64(0.3677122101191622), 'max_depth': 29, 'min_child_samples': 111, 'min_child_weight': 13, 'n_estimators': 86, 'num_leaves': 151}
# Melhor score geral até agora: 0.5174
#
# Busca 18/20...
# Melhor score desta busca: 0.5075
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.8742967462597884), 'bagging_freq': 11, 'feature_fraction': np.float64(0.1379986387058598), 'lambda_l1': np.float64(0.7753973302959695), 'lambda_l2': np.float64(2.213981073418249), 'learning_rate': np.float64(0.22968646796420814), 'max_depth': 28, 'min_child_samples': 91, 'min_child_weight': 5, 'n_estimators': 46, 'num_leaves': 69}
# Melhor score geral até agora: 0.5174
#
# Busca 19/20...
# Melhor score desta busca: 0.4700
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.9071284728424656), 'bagging_freq': 64, 'feature_fraction': np.float64(0.4049999274946747), 'lambda_l1': np.float64(1.3512804364485695), 'lambda_l2': np.float64(2.0913680634768816), 'learning_rate': np.float64(0.22258509318776057), 'max_depth': 15, 'min_child_samples': 54, 'min_child_weight': 12, 'n_estimators': 60, 'num_leaves': 50}
# Melhor score geral até agora: 0.5174
#
# Busca 20/20...
# Melhor score desta busca: 0.5276
# Melhor configuração desta busca: {'bagging_fraction': np.float64(0.8225062435950373), 'bagging_freq': 46, 'feature_fraction': np.float64(0.1673595884495446), 'lambda_l1': np.float64(1.6653041558643404), 'lambda_l2': np.float64(1.5560712137382917), 'learning_rate': np.float64(0.14312325922398775), 'max_depth': 26, 'min_child_samples': 87, 'min_child_weight': 6, 'n_estimators': 134, 'num_leaves': 199}
# Melhor score geral até agora: 0.5276
#
# 🎯 Busca completa! Melhor score geral: 0.5276
# Total de configurações testadas: 400
#
# --- RESULTADOS LightGBM ---
# Melhores hiperparâmetros encontrados:
#   bagging_fraction: 0.8225062435950373
#   bagging_freq: 46
#   feature_fraction: 0.1673595884495446
#   lambda_l1: 1.6653041558643404
#   lambda_l2: 1.5560712137382917
#   learning_rate: 0.14312325922398775
#   max_depth: 26
#   min_child_samples: 87
#   min_child_weight: 6
#   n_estimators: 134
#   num_leaves: 199
#
# Melhor F1-Score (CV): 0.5276
# Desvio padrão: 0.0244

# %% [markdown]
# ### 5.3 Visualizar Histórico da Busca

# %%
# Registro de Desempenho - plotar evolução da busca
plot_search_history(all_searches, search, MODEL_NAME)

# %%
# ======================================================================
# ANÁLISE DAS MELHORES CONFIGURAÇÕES ENCONTRADAS
# ======================================================================

print(f"=== MELHORES CONFIGURAÇÕES ENCONTRADAS POR BUSCA - {MODEL_NAME} ===")

# Extrair os melhores resultados de cada busca
best_configs = []

for i, search_result in enumerate(all_searches):
    config = {
        'Busca': i + 1,
        'F1_Score': search_result['best_score'],
        **search_result['best_params']
    }
    best_configs.append(config)

# Criar DataFrame e exibir top configs
results_df = pd.DataFrame(best_configs)
results_df = results_df.sort_values('F1_Score', ascending=False).round(4)

print(f"\nTop configurações (de {len(results_df)} buscas):")
print(results_df.to_string(index=False))

print(f"\nEstatísticas dos F1-Scores encontrados:")
print(f"  Média: {results_df['F1_Score'].mean():.4f}")
print(f"  Mediana: {results_df['F1_Score'].median():.4f}")
print(f"  Desvio padrão: {results_df['F1_Score'].std():.4f}")
print(f"  Min: {results_df['F1_Score'].min():.4f}")
print(f"  Max: {results_df['F1_Score'].max():.4f}")
# Out:
# === MELHORES CONFIGURAÇÕES ENCONTRADAS POR BUSCA - LightGBM ===
#
# Top configurações (de 20 buscas):
#  Busca  F1_Score  bagging_fraction  bagging_freq  feature_fraction  lambda_l1  lambda_l2  learning_rate  max_depth  min_child_samples  min_child_weight  n_estimators  num_leaves
#     20    0.5276            0.8225            46            0.1674     1.6653     1.5561         0.1431         26                 87                 6           134         199
#      9    0.5174            0.9129            44            0.1585     1.9002     2.0474         0.1788         29                 73                 6            70         163
#      2    0.5170            0.9357            57            0.5047     1.7704     2.4412         0.1497         14                106                 7           149         118
#     15    0.5090            0.8510            49            0.5034     1.3052     1.9416         0.2260         20                 82                 4           129         127
#     18    0.5075            0.8743            11            0.1380     0.7754     2.2140         0.2297         28                 91                 5            46          69
#      6    0.5043            0.9403            58            0.1368     1.8275     1.7019         0.2548         15                 51                 8            78         154
#      8    0.5008            0.8672            12            0.4671     0.9766     2.4536         0.2560         20                109                 5           101         121
#      3    0.5006            0.9298            21            0.5497     1.6804     1.4399         0.2671         15                104                 4            54         122
#      4    0.4989            0.8891            50            0.5009     1.8875     1.1236         0.3536         17                 83                 4           137         182
#     13    0.4985            0.8300            42            0.5965     1.8429     2.4751         0.1678         16                118                 6            59          65
#      5    0.4931            0.7403            29            0.5457     0.6274     1.6241         0.1321         15                106                 7           136         165
#     16    0.4831            0.9238            46            0.3760     1.9196     1.0974         0.2664         21                 88                 9           147         129
#     10    0.4829            0.9242            27            0.5431     0.5162     2.3894         0.3070         23                 89                 9           111         176
#      7    0.4734            0.6587            53            0.2371     1.1593     2.3872         0.1030         11                 58                 7           104          58
#      1    0.4721            0.7266            48            0.3111     1.8785     1.4710         0.1284         29                 59                10           104         168
#     14    0.4704            0.8935            40            0.1806     0.7183     2.2164         0.5054         27                 74                 6            36         128
#     11    0.4703            0.8273            69            0.5902     0.8424     1.5810         0.3464         18                 95                 6            44         176
#     19    0.4700            0.9071            64            0.4050     1.3513     2.0914         0.2226         15                 54                12            60          50
#     17    0.4699            0.8995            68            0.5607     1.1939     2.2845         0.3677         29                111                13            86         151
#     12    0.4577            0.8343            23            0.4647     0.7901     2.2489         0.1447         29                 89                15            95         125
#
# Estatísticas dos F1-Scores encontrados:
#   Média: 0.4912
#   Mediana: 0.4958
#   Desvio padrão: 0.0198
#   Min: 0.4577
#   Max: 0.5276

# %% [markdown]
# ## 6. Salvar Resultados de Busca

# %%
search_df = save_search_results(
    model_name=MODEL_NAME,
    model_search=search,
    model_all_searches=all_searches,
    n_searches=N_SEARCHES,
    n_iter_per_search=N_ITER_PER_SEARCH,
    scoring=SCORING_METRIC,
    cv_folds=DEFAULT_CV_STRATEGY.get_n_splits(),
    top_params_columns=param_distributions.keys(),
    searches_folder=SEARCHES_FOLDER
)
# Out:
# === SALVANDO RESULTADOS DA BUSCA - LIGHTGBM ===
#   ✅ Todos os Resultados salvos: searches\lightgbm_all_searches.csv
#   Total de configurações testadas: 400
#   ✅ Resumo salvo: searches\lightgbm_search_summary.json
#
# --- ESTATÍSTICAS DA BUSCA LIGHTGBM ---
# Melhor F1-Score: 0.5276
# Desvio padrão do melhor: 0.0244
# F1-Score médio geral: 0.3902
# F1-Score mínimo: 0.2247
# F1-Score máximo: 0.5276

# %% [markdown]
# ### 6.2 Carregar Resultado de Busca (Opcional)

# %%
loaded_results = load_search_results(MODEL_NAME)

# %%
# Plotar a história da busca a partir dos resultados carregados
plot_search_history_from_loaded(loaded_results, MODEL_NAME)

# %% [markdown]
# ### 6.3 Definir Melhores Params e CV score

# %%
# Definir Melhores Parâmetros para Uso Posterior
if 'loaded_results' in locals():
    best_params = get_best_params_from_saved(MODEL_NAME)
    best_score = loaded_results['summary']['best_overall_score']
    print(f"✅ Usando parâmetros carregados: {best_params}")
    print(f"✅ Melhor F1-Score carregado: {best_score:.4f}")
else:
    best_params = search.best_params_
    best_score = search.best_score_
    print(f"✅ Usando parâmetros da busca atual: {best_params}")
    print(f"✅ Melhor F1-Score da busca atual: {best_score:.4f}")

# %% [markdown]
# ## 7. Treinar Modelo Final e Salvar

# %%
# Treinamento Final com melhores hiperparâmetros

best_model = MODEL_CLASS(random_state=RANDOM_STATE_MODEL, **best_params)
best_model.fit(X_train_scaled, y_train)
print(f"\nModelo final {MODEL_NAME} treinado com dataset completo: {best_model}")

# %%
# Save the trained model immediately after training
os.makedirs(MODELS_FOLDER, exist_ok=True)

model_path = os.path.join(MODELS_FOLDER, f'{MODEL_NAME.lower().replace(" ", "_")}_model.joblib')
dump(best_model, model_path)
print(f"✅ Model saved to: {model_path}")

# %% [markdown]
# ## 8. Avaliação Final e Salvamento dos Resultados

# %%
# Carregar modelo (Opcional)
loaded_model = load(os.path.join(MODELS_FOLDER, f'{MODEL_NAME.lower().replace(" ", "_")}_model.joblib'))

# %%
print(f"=== AVALIAÇÃO E SALVAMENTO DOS RESULTADOS - {MODEL_NAME} ===")

# Criar pastas se não existirem
os.makedirs(RESULTS_FOLDER, exist_ok=True)

# Avaliação completa do modelo
print("\nAvaliando performance do modelo...")

# Usar datasets completos para avaliação final
X_train_eval = X_train_scaled
y_train_eval = y_train
X_test_eval = X_test_scaled
y_test_eval = y_test

# Avaliar modelo usando função do módulo
train_metrics, test_metrics, y_test_pred = evaluate_model(
    best_model, X_train_eval, X_test_eval, y_train_eval, y_test_eval, MODEL_NAME
)

# %% [markdown]
# ### 8.1 Classification Report

# %%
print(classification_report(y_test_eval, y_test_pred, zero_division=0))

# %% [markdown]
# ### 8.2 Visualize Confusion Matrix

# %%
# Plot confusion matrix
cm = confusion_matrix(y_test_eval, y_test_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=True)
plt.title(f'{MODEL_NAME} - Confusion Matrix (Test Set)')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8.3 Save Final Results

# %%
# Salvar resultados finais usando função do módulo
model_final_results = save_final_results(
    model_name=MODEL_NAME,
    best_params=best_params,
    best_score=best_score,
    train_metrics=train_metrics,
    test_metrics=test_metrics,
    y_pred=y_test_pred,
    y_test=y_test_eval,
    X_train_scaled=X_train_eval,
    X_test_scaled=X_test_eval,
    results_folder=RESULTS_FOLDER
)

# Mostrar resumo final
print(f"\n--- RESUMO FINAL {MODEL_NAME} ---")
print(f"F1-Score CV: {model_final_results['best_cv_score']:.4f}")
print(f"F1-Score Teste: {test_metrics['f1']:.4f}")
print(f"Acurácia Teste: {test_metrics['accuracy']:.4f}")
print(f"Precisão Teste: {test_metrics['precision']:.4f}")
print(f"Recall Teste: {test_metrics['recall']:.4f}")
print(f"G-Mean Teste: {test_metrics['gmean']:.4f}")

print(f"Resultados salvos em: {RESULTS_FOLDER}/")
print(f"\nAvaliação do {MODEL_NAME} concluída com sucesso!")
